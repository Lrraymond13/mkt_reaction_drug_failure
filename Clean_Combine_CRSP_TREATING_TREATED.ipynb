# %%
# This notebook imports CRSP data, combines and cleans it, creating full data set
# also creates a combined stock price plus treating treated event flag data set

# %%
# Combine and Clean CRSP Data
import cPickle as pickle
from datetime import datetime
import funcy
import itertools
import numpy as np
import pandas as pd
import plotly
from plotly import tools
import plotly.plotly as py
import plotly.graph_objs as go
import pytz
import os

from analysis.utilities.data_utils import clean_columns, strip_upcase
from analysis.utilities.dropbox_client import DropboxAPI

DROPBOX_ANALYSIS_DATA = '/data/intermediate'
DROPBOX_DATA = '/data'
DATA = os.path.join(os.path.abspath(os.curdir), 'analysis/Data')
TAB_CRSP_FILES = ['output1-50.txt', 'output51-100.txt', 'output101-150.txt']
CSV_CRSP_FILES = ['output_200+.csv']
TT_FNAME = 'treating_treated_ticker'
FULL_CSP_FNAME = 'full_CRSP'
CRSP_LONG_FNAME = 'PRC_RET_VOL_long'
CRSP_FLAG_FNAME = 'crsp_event_flags'
# This compiles all current CRSP data, reads in treating_treated data set and does some summary data viz

# %%
TTYPES = ['TREATING', 'TREATED']
TREATING = 'TREATING'
TREATED = 'TREATED'
TREATING_DT = 'TREATING_DISCONTINUED_IKT_DATE'
TREATED_DT = 'DISCONTINUED_IKT_DATE'
FLAGS = ['SAMEMKT_SAMETECH', 'SAMEMKT_DIFFTECH', 'DIFFMKT_SAMETECH']

# %%
PIVOTS = ['RET', 'VOL', 'PRC']

# %%
UPLOAD_DATA = True

# %%
d = DropboxAPI()

# %%
crsp_csv = [d.search_and_download(f, DROPBOX_DATA, DATA, ',') for f in CSV_CRSP_FILES]
crsp_tab = [d.search_and_download(f, DROPBOX_DATA, DATA, '\t') for f in TAB_CRSP_FILES]
# Out:
# Searching output_200+.csv in path /data
# Results found in dropbox, downloading /data/crsp/output_200+.csv
# downloading /data/crsp/output_200+.csv
# /Users/lrraymond13/.virtualenvs/ds3/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2825: DtypeWarning:
#
# Columns (9,48,56) have mixed types. Specify dtype option on import or set low_memory=False.
# Searching output1-50.txt in path /data
# Results found in dropbox, downloading /data/crsp/output1-50.txt
# downloading /data/crsp/output1-50.txt
# Searching output51-100.txt in path /data
# Results found in dropbox, downloading /data/crsp/output51-100.txt
# downloading /data/crsp/output51-100.txt
# Searching output101-150.txt in path /data
# Results found in dropbox, downloading /data/crsp/output101-150.txt
# downloading /data/crsp/output101-150.txt

# %%
# Concatenate all CRSP files
ds = pd.concat(crsp_tab, axis=0)
ds2 = pd.concat(crsp_csv, axis=0)

# %%
ds.columns = map(str.upper, ds.columns)
ds2.columns = map(str.upper, ds2.columns)
print ds2.columns
# Out:
# Index([u'PERMNO', u'DATE', u'NAMEENDT', u'SHRCD', u'EXCHCD', u'SICCD',
#        u'NCUSIP', u'TICKER', u'COMNAM', u'SHRCLS', u'TSYMBOL', u'NAICS',
#        u'PRIMEXCH', u'TRDSTAT', u'SECSTAT', u'PERMCO', u'ISSUNO', u'HEXCD',
#        u'HSICCD', u'CUSIP', u'DCLRDT', u'DLAMT', u'DLPDT', u'DLSTCD',
#        u'NEXTDT', u'PAYDT', u'RCRDDT', u'SHRFLG', u'HSICMG', u'HSICIG',
#        u'DISTCD', u'DIVAMT', u'FACPR', u'FACSHR', u'ACPERM', u'ACCOMP',
#        u'NWPERM', u'DLRETX', u'DLPRC', u'DLRET', u'TRTSCD', u'NMSIND',
#        u'MMCNT', u'NSDINX', u'BIDLO', u'ASKHI', u'PRC', u'VOL', u'RET', u'BID',
#        u'ASK', u'SHROUT', u'CFACPR', u'CFACSHR', u'OPENPRC', u'NUMTRD',
#        u'RETX', u'VWRETD', u'VWRETX', u'EWRETD', u'EWRETX', u'SPRTRN'],
#       dtype='object')

# %%
# change date column to a date objct
# Note that the two types of files have different date formats
# This process generally takes about 2 minutes
ds2['DATE_OBJ']= ds2['DATE'].apply(lambda x: pd.to_datetime(x, format='%Y%m%d'))
ds['DATE_OBJ']= ds['DATE'].apply(lambda x: pd.to_datetime(x, format='%m/%d/%Y'))

# %%
# concat the two data sets together
ds_merged = ds2.append(ds, ignore_index=True)

# %%
# drop date column because its now meaningless
ds_merged.drop('DATE', axis=1, inplace=True)

# %%
# check for duplicate data downloads in data set
ds_merged.sort_values(by=['TICKER', 'DATE_OBJ'], inplace=True)

# drop return column and join with serires of coerced numeric values
ds_merged2 = ds_merged.drop(['PERMNO', 'PERMCO', 'PRC', 'VOL', 'RET', 'NUMTRD', 'RETX', 'SPRTRN'], axis=1).join(ds_merged[
        ['PERMNO', 'PERMCO', 'PRC', 'VOL', 'RET', 'NUMTRD', 'RETX', 'SPRTRN']].apply(pd.to_numeric, errors='coerce'))

# %%
# Check for duplicate dates
ds_merged2.loc[ds_merged.duplicated(['TICKER', 'DATE_OBJ'], keep=False), ['TICKER', 'DATE_OBJ', 'PRC']]
# Out:
#        TICKER   DATE_OBJ     PRC
# 367006    ACL 2011-04-11     NaN
# 367007    ACL 2011-04-11     NaN
# 354597   ADLR 2011-12-12     NaN
# 354598   ADLR 2011-12-12     NaN
# 159676    AGN 2015-03-17     NaN
# 159677    AGN 2015-03-17     NaN
# 378660   ANIP 2013-07-18  7.1490
# 610984   ANIP 2013-07-18  7.1490
# 378661   ANIP 2013-07-19  7.0000
# 610985   ANIP 2013-07-19  7.0000
# 378662   ANIP 2013-07-22  6.9800
# 610986   ANIP 2013-07-22  6.9800
# 378663   ANIP 2013-07-23  7.0400
# 610987   ANIP 2013-07-23  7.0400
# 378664   ANIP 2013-07-24  7.1100
# 610988   ANIP 2013-07-24  7.1100
# 378665   ANIP 2013-07-25  7.2799
# 610989   ANIP 2013-07-25  7.2799
# 378666   ANIP 2013-07-26  7.2900
# 610990   ANIP 2013-07-26  7.2900
# 378667   ANIP 2013-07-29  7.4000
# 610991   ANIP 2013-07-29  7.4000
# 378668   ANIP 2013-07-30  7.2400
# 610992   ANIP 2013-07-30  7.2400
# 378669   ANIP 2013-07-31  6.9399
# 610993   ANIP 2013-07-31  6.9399
# 378670   ANIP 2013-08-01  6.6000
# 610994   ANIP 2013-08-01  6.6000
# 378671   ANIP 2013-08-02  6.5690
# 610995   ANIP 2013-08-02  6.5690
# ...       ...        ...     ...
# 234355    NaN 2015-07-31     NaN
# 263771    NaN 2015-07-31     NaN
# 234356    NaN 2015-08-03     NaN
# 263772    NaN 2015-08-03     NaN
# 234357    NaN 2015-08-04     NaN
# 263773    NaN 2015-08-04     NaN
# 234358    NaN 2015-08-05     NaN
# 263774    NaN 2015-08-05     NaN
# 234359    NaN 2015-08-06     NaN
# 263775    NaN 2015-08-06     NaN
# 234360    NaN 2015-08-07     NaN
# 263776    NaN 2015-08-07     NaN
# 234361    NaN 2015-08-10     NaN
# 263777    NaN 2015-08-10     NaN
# 234362    NaN 2015-08-11     NaN
# 263778    NaN 2015-08-11     NaN
# 234363    NaN 2015-08-12     NaN
# 263779    NaN 2015-08-12     NaN
# 234364    NaN 2015-08-13     NaN
# 263780    NaN 2015-08-13     NaN
# 234365    NaN 2015-08-14     NaN
# 263781    NaN 2015-08-14     NaN
# 234366    NaN 2015-08-17     NaN
# 263782    NaN 2015-08-17     NaN
# 234367    NaN 2015-08-18     NaN
# 263783    NaN 2015-08-18     NaN
# 234368    NaN 2015-08-19     NaN
# 263784    NaN 2015-08-19     NaN
# 234369    NaN 2015-08-20     NaN
# 263785    NaN 2015-08-20     NaN
#
# [124565 rows x 3 columns]

# %%
# drop duplicates possibly from duplicate downloads of same ticker, Nans should show up first 
# sorted 
ds_short = ds_merged2.drop_duplicates(subset=['TICKER', 'DATE_OBJ'], keep='last')

# %%
# When CRSP doesn't have a final closing price, they will use the average of the bid/ask spread and denote this with a - sign
# we don't want neg stock values, so the price column is reassigned to the abs()
ds_short.rename(columns={'PRC': 'PRC_NEGATIVE'}, inplace=True)
ds_short.loc[:, 'PRC'] = ds_short['PRC_NEGATIVE'].abs()
# Out:
# /Users/lrraymond13/.virtualenvs/ds3/lib/python2.7/site-packages/pandas/core/frame.py:2754: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/lrraymond13/.virtualenvs/ds3/lib/python2.7/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/lrraymond13/.virtualenvs/ds3/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
del ds, ds2, ds_merged, ds_merged2

# %%
# pickle result and upload to dropbox
if UPLOAD_DATA:
    d.pickle_upload_dataset(ds_short, '{}.p'.format(FULL_CSP_FNAME), DATA, DROPBOX_DATA)
# Out:
# Serializing to local path /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/full_CRSP.p
# Uploading /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/full_CRSP.p to Dropbox as /data/full_CRSP.p

# %%
# Create pivot-ed data set versions for both price and returns

pivot_fnc = lambda x: pd.pivot_table(ds_short, values=x, index='DATE_OBJ', columns='TICKER')
frames = []
for p in PIVOTS:
    # create pivot_dataframe
    x = None
    x = pivot_fnc(p)
    x.columns = map(lambda x: '{0}_{1}'.format(x, p), x.columns)
    frames.append(x)

# %%
m1 = pd.merge(frames[0], frames[1], left_index=True, right_index=True, how='outer')
m2 =  pd.merge(m1, frames[2], left_index=True, right_index=True, how='outer')

# %%
del m1, frames

# %%
# sort columns
m2 = m2[sorted(m2.columns)]

# %%
# Save dataset
if UPLOAD_DATA:
    d.pickle_upload_dataset(m2, '{}.p'.format(CRSP_LONG_FNAME), DATA, DROPBOX_ANALYSIS_DATA)
# Out:
# Serializing to local path /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/PRC_RET_VOL_long.p
# Uploading /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/PRC_RET_VOL_long.p to Dropbox as /data/intermediate/PRC_RET_VOL_long.p

# %%
m2.head()
# Out:
#             ABBV_PRC  ABBV_RET  ABBV_VOL  ABEO_PRC  ABEO_RET  ABEO_VOL  \
# DATE_OBJ
# 1990-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN       NaN       NaN       NaN
#
#             ABIO_PRC  ABIO_RET  ABIO_VOL  ABT_PRC    ...     ZFGN_VOL  \
# DATE_OBJ                                             ...
# 1990-01-02       NaN       NaN       NaN      NaN    ...          NaN
# 1990-01-03       NaN       NaN       NaN      NaN    ...          NaN
# 1990-01-04       NaN       NaN       NaN      NaN    ...          NaN
# 1990-01-05       NaN       NaN       NaN      NaN    ...          NaN
# 1990-01-08       NaN       NaN       NaN      NaN    ...          NaN
#
#             ZGNX_PRC  ZGNX_RET  ZGNX_VOL  ZIOP_PRC  ZIOP_RET  ZIOP_VOL  \
# DATE_OBJ
# 1990-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN       NaN       NaN       NaN
#
#             ZSAN_PRC  ZSAN_RET  ZSAN_VOL
# DATE_OBJ
# 1990-01-02       NaN       NaN       NaN
# 1990-01-03       NaN       NaN       NaN
# 1990-01-04       NaN       NaN       NaN
# 1990-01-05       NaN       NaN       NaN
# 1990-01-08       NaN       NaN       NaN
#
# [5 rows x 1263 columns]

# %%
# Read in Treating/Treated Data Set
# r = d.search('{}.csv'.format(TT_FNAME), False)
tt_ds = d.search_and_download('{}'.format(TT_FNAME), DROPBOX_ANALYSIS_DATA, DATA, ',', False)

#  date columns to date without time resolution
tt_ds[TREATED_DT]= tt_ds[TREATED_DT].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d'))
tt_ds[TREATING_DT]= tt_ds[TREATING_DT].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d'))
# Out:
# Searching local path
# Full path /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/treating_treated_ticker.csv

# %%
# Pickle Data Set and Save to Dropbox
if UPLOAD_DATA:
    d.pickle_upload_dataset(tt_ds, '{}.p'.format(TT_FNAME), DATA, DROPBOX_ANALYSIS_DATA)
# Out:
# Serializing to local path /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/treating_treated_ticker.p
# Uploading /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/treating_treated_ticker.p to Dropbox as /data/intermediate/treating_treated_ticker.p

# %%
def get_ticker_events(ticker, flag, ttype, event_df, date_cols=[TREATED_DT, TREATING_DT]):
    # get dates where ticker flagged for 'flag_name' event
    # get instances where treating/treated ticker symbol == to ticker type
    # ticker is ticker symbol, flag is string of 'Treating_
    parent_ts = '{}_PARENT_TICKER_SYMBOL'.format(ttype)
    ts = '{}_TICKER_SYMBOL'.format(ttype)
    events = event_df[(event_df[parent_ts].isin([ticker])) | (event_df[ts].isin([ticker]))]
    
    # find dates where each specific flag has value for this ticker, if none, continue to next flag
    if len(events) == 0:
        return None
    event_dates = events.loc[events[flag] > 0, funcy.concat(date_cols, [flag])]
    return event_dates

# %%
# Pickle and read in treating treated data set
# create long version of data set
# for each ticker, create columns with flag for 6 different options
# flag_cols = ['{0}_{1}'.format(t, f) for (t, f) in itertools.product(TTYPES, FLAGS)],
def create_event_flag_series(ticker, flag, ttype, event_df, dt_var=TREATING_DT):
    series_name = '{0}_{1}_{2}'.format(ticker, ttype, flag)
    ticker_series = None
    events_df = get_ticker_events(ticker, flag, ttype, event_df)
    if events_df is None or events_df.empty:
        print('{} has no events'.format(series_name))
        return None
    event_dates = events_df[dt_var].unique()
    print('{} has {} events'.format(series_name, len(events_df)))
    # create series using only unique dates (multiple events may happen on same day)
    ticker_series = pd.Series(1, index=pd.DatetimeIndex(event_dates))
    ticker_series.rename(series_name, inplace=True)
    return ticker_series

# %%
tt_ds.loc[:, [TREATED_DT, TREATING_DT]]
# Out:
#        DISCONTINUED_IKT_DATE TREATING_DISCONTINUED_IKT_DATE
# 0                        NaT                     2000-08-03
# 1                        NaT                     2000-08-03
# 2                 2001-10-16                     2000-08-03
# 3                 2001-11-16                     2000-08-03
# 4                 2003-05-12                     2000-08-03
# 5                 2001-10-04                     2000-08-03
# 6                        NaT                     2000-08-03
# 7                        NaT                     2000-08-03
# 8                 2001-11-16                     2000-08-03
# 9                 2003-05-12                     2000-08-03
# 10                       NaT                     2000-08-03
# 11                       NaT                     2000-08-03
# 12                       NaT                     2000-08-03
# 13                       NaT                     2000-08-03
# 14                       NaT                     2000-08-03
# 15                2001-10-04                     2000-08-03
# 16                2003-05-12                     2000-08-03
# 17                2008-10-01                     2000-08-03
# 18                       NaT                     2000-08-03
# 19                       NaT                     2000-08-03
# 20                       NaT                     2000-08-03
# 21                       NaT                     2000-08-03
# 22                       NaT                     2000-08-03
# 23                2001-10-12                     2000-08-03
# 24                       NaT                     2000-08-03
# 25                2008-10-01                     2000-08-03
# 26                2001-10-01                     2000-08-03
# 27                       NaT                     2000-11-22
# 28                       NaT                     2000-11-22
# 29                       NaT                     2000-11-22
# ...                      ...                            ...
# 318228                   NaT                     2013-01-23
# 318229                   NaT                     2013-01-23
# 318230                   NaT                     2013-01-23
# 318231                   NaT                     2013-01-23
# 318232                   NaT                     2013-01-23
# 318233                   NaT                     2013-01-23
# 318234                   NaT                     2013-01-23
# 318235            2013-07-31                     2013-01-23
# 318236            2013-07-31                     2013-01-23
# 318237                   NaT                     2013-01-23
# 318238                   NaT                     2013-01-23
# 318239                   NaT                     2013-01-23
# 318240            2013-07-31                     2013-01-23
# 318241                   NaT                     2013-01-23
# 318242                   NaT                     2013-01-23
# 318243                   NaT                     2013-01-23
# 318244                   NaT                     2013-01-23
# 318245                   NaT                     2013-01-23
# 318246                   NaT                     2013-01-23
# 318247                   NaT                     2013-01-23
# 318248                   NaT                     2013-01-23
# 318249                   NaT                     2013-01-23
# 318250                   NaT                     2013-01-23
# 318251                   NaT                     2013-01-23
# 318252                   NaT                     2013-01-23
# 318253                   NaT                     2013-01-23
# 318254                   NaT                     2013-01-23
# 318255            2013-07-31                     2013-01-23
# 318256                   NaT                     2013-01-23
# 318257                   NaT                     2013-01-23
#
# [318258 rows x 2 columns]

# %%
def create_own_drug_disc_dates(ticker, event_df):
    # for each ticker, get unique dates when either it is a treating event OR 
    # a drug is discontinued when it is in the treated group
    treating_parent_ts = '{}_PARENT_TICKER_SYMBOL'.format(TREATING)
    treating_ts = '{}_TICKER_SYMBOL'.format(TREATING)
    treated_parent_ts = '{}_PARENT_TICKER_SYMBOL'.format(TREATED)
    treated_ts = '{}_TICKER_SYMBOL'.format(TREATED)
    # get dates of when in treated group and discontinues drug
    # when compnay is in the treated group and has a drug disc date in treated datetime
    own_fails = event_df.loc[
        (event_df[treated_parent_ts] == ticker) | (event_df[treated_ts] == ticker), TREATED_DT].dropna().unique()
    treating_fails = event_df.loc[
        (event_df[treating_parent_ts] == ticker) | (event_df[treating_ts] == ticker), TREATING_DT].dropna().unique()
    fails = pd.Series(1, index=pd.DatetimeIndex(np.concatenate([own_fails, treating_fails], axis=0)))
    # remove duplicates
    grouped = fails.groupby(level=0)
    fails2 = grouped.last()
    fails_name = '{0}_DISC'.format(ticker)
    fails2.rename(fails_name, inplace=True)
    return fails2.sort_index()

# %%
UNIQUE_TICKERS = ds_short.TICKER.dropna().unique()

flag_series = [
    create_event_flag_series(ticker, flag, ttype, tt_ds)
        for ticker in UNIQUE_TICKERS for ttype in TTYPES for flag in FLAGS]
# Out:
# AB_TREATING_SAMEMKT_SAMETECH has no events
# AB_TREATING_SAMEMKT_DIFFTECH has no events
# AB_TREATING_DIFFMKT_SAMETECH has no events
# AB_TREATED_SAMEMKT_SAMETECH has no events
# AB_TREATED_SAMEMKT_DIFFTECH has 486 events
# AB_TREATED_DIFFMKT_SAMETECH has 76 events
# ABBV_TREATING_SAMEMKT_SAMETECH has 12 events
# ABBV_TREATING_SAMEMKT_DIFFTECH has 2141 events
# ABBV_TREATING_DIFFMKT_SAMETECH has 55 events
# ABBV_TREATED_SAMEMKT_SAMETECH has 2 events
# ABBV_TREATED_SAMEMKT_DIFFTECH has 437 events
# ABBV_TREATED_DIFFMKT_SAMETECH has 31 events
# ABEO_TREATING_SAMEMKT_SAMETECH has no events
# ABEO_TREATING_SAMEMKT_DIFFTECH has no events
# ABEO_TREATING_DIFFMKT_SAMETECH has no events
# ABEO_TREATED_SAMEMKT_SAMETECH has 1 events
# ABEO_TREATED_SAMEMKT_DIFFTECH has 307 events
# ABEO_TREATED_DIFFMKT_SAMETECH has 14 events
# ABIO_TREATING_SAMEMKT_SAMETECH has no events
# ABIO_TREATING_SAMEMKT_DIFFTECH has 146 events
# ABIO_TREATING_DIFFMKT_SAMETECH has no events
# ABIO_TREATED_SAMEMKT_SAMETECH has no events
# ABIO_TREATED_SAMEMKT_DIFFTECH has 89 events
# ABIO_TREATED_DIFFMKT_SAMETECH has no events
# ABT_TREATING_SAMEMKT_SAMETECH has 37 events
# ABT_TREATING_SAMEMKT_DIFFTECH has 2446 events
# ABT_TREATING_DIFFMKT_SAMETECH has 283 events
# ABT_TREATED_SAMEMKT_SAMETECH has 62 events
# ABT_TREATED_SAMEMKT_DIFFTECH has 3574 events
# ABT_TREATED_DIFFMKT_SAMETECH has 511 events
# ABUS_TREATING_SAMEMKT_SAMETECH has no events
# ABUS_TREATING_SAMEMKT_DIFFTECH has 62 events
# ABUS_TREATING_DIFFMKT_SAMETECH has no events
# ABUS_TREATED_SAMEMKT_SAMETECH has no events
# ABUS_TREATED_SAMEMKT_DIFFTECH has 138 events
# ABUS_TREATED_DIFFMKT_SAMETECH has no events
# ACAD_TREATING_SAMEMKT_SAMETECH has no events
# ACAD_TREATING_SAMEMKT_DIFFTECH has 64 events
# ACAD_TREATING_DIFFMKT_SAMETECH has 3 events
# ACAD_TREATED_SAMEMKT_SAMETECH has no events
# ACAD_TREATED_SAMEMKT_DIFFTECH has 57 events
# ACAD_TREATED_DIFFMKT_SAMETECH has no events
# ACE_TREATING_SAMEMKT_SAMETECH has no events
# ACE_TREATING_SAMEMKT_DIFFTECH has no events
# ACE_TREATING_DIFFMKT_SAMETECH has no events
# ACE_TREATED_SAMEMKT_SAMETECH has no events
# ACE_TREATED_SAMEMKT_DIFFTECH has no events
# ACE_TREATED_DIFFMKT_SAMETECH has no events
# ACEL_TREATING_SAMEMKT_SAMETECH has no events
# ACEL_TREATING_SAMEMKT_DIFFTECH has 18 events
# ACEL_TREATING_DIFFMKT_SAMETECH has 3 events
# ACEL_TREATED_SAMEMKT_SAMETECH has no events
# ACEL_TREATED_SAMEMKT_DIFFTECH has 235 events
# ACEL_TREATED_DIFFMKT_SAMETECH has no events
# ACHN_TREATING_SAMEMKT_SAMETECH has no events
# ACHN_TREATING_SAMEMKT_DIFFTECH has no events
# ACHN_TREATING_DIFFMKT_SAMETECH has no events
# ACHN_TREATED_SAMEMKT_SAMETECH has no events
# ACHN_TREATED_SAMEMKT_DIFFTECH has 29 events
# ACHN_TREATED_DIFFMKT_SAMETECH has no events
# ACL_TREATING_SAMEMKT_SAMETECH has no events
# ACL_TREATING_SAMEMKT_DIFFTECH has 416 events
# ACL_TREATING_DIFFMKT_SAMETECH has 2 events
# ACL_TREATED_SAMEMKT_SAMETECH has no events
# ACL_TREATED_SAMEMKT_DIFFTECH has 355 events
# ACL_TREATED_DIFFMKT_SAMETECH has 13 events
# ACOR_TREATING_SAMEMKT_SAMETECH has no events
# ACOR_TREATING_SAMEMKT_DIFFTECH has no events
# ACOR_TREATING_DIFFMKT_SAMETECH has 2 events
# ACOR_TREATED_SAMEMKT_SAMETECH has no events
# ACOR_TREATED_SAMEMKT_DIFFTECH has 7 events
# ACOR_TREATED_DIFFMKT_SAMETECH has 3 events
# ACRX_TREATING_SAMEMKT_SAMETECH has no events
# ACRX_TREATING_SAMEMKT_DIFFTECH has no events
# ACRX_TREATING_DIFFMKT_SAMETECH has no events
# ACRX_TREATED_SAMEMKT_SAMETECH has no events
# ACRX_TREATED_SAMEMKT_DIFFTECH has 85 events
# ACRX_TREATED_DIFFMKT_SAMETECH has 5 events
# ACT_TREATING_SAMEMKT_SAMETECH has no events
# ACT_TREATING_SAMEMKT_DIFFTECH has no events
# ACT_TREATING_DIFFMKT_SAMETECH has no events
# ACT_TREATED_SAMEMKT_SAMETECH has no events
# ACT_TREATED_SAMEMKT_DIFFTECH has no events
# ACT_TREATED_DIFFMKT_SAMETECH has no events
# ACTI_TREATING_SAMEMKT_SAMETECH has no events
# ACTI_TREATING_SAMEMKT_DIFFTECH has 308 events
# ACTI_TREATING_DIFFMKT_SAMETECH has 2 events
# ACTI_TREATED_SAMEMKT_SAMETECH has no events
# ACTI_TREATED_SAMEMKT_DIFFTECH has 298 events
# ACTI_TREATED_DIFFMKT_SAMETECH has 2 events
# ACU_TREATING_SAMEMKT_SAMETECH has no events
# ACU_TREATING_SAMEMKT_DIFFTECH has 116 events
# ACU_TREATING_DIFFMKT_SAMETECH has no events
# ACU_TREATED_SAMEMKT_SAMETECH has 2 events
# ACU_TREATED_SAMEMKT_DIFFTECH has 112 events
# ACU_TREATED_DIFFMKT_SAMETECH has 9 events
# ACUS_TREATING_SAMEMKT_SAMETECH has no events
# ACUS_TREATING_SAMEMKT_DIFFTECH has no events
# ACUS_TREATING_DIFFMKT_SAMETECH has no events
# ACUS_TREATED_SAMEMKT_SAMETECH has no events
# ACUS_TREATED_SAMEMKT_DIFFTECH has 1 events
# ACUS_TREATED_DIFFMKT_SAMETECH has no events
# ADHD_TREATING_SAMEMKT_SAMETECH has no events
# ADHD_TREATING_SAMEMKT_DIFFTECH has no events
# ADHD_TREATING_DIFFMKT_SAMETECH has no events
# ADHD_TREATED_SAMEMKT_SAMETECH has no events
# ADHD_TREATED_SAMEMKT_DIFFTECH has 6 events
# ADHD_TREATED_DIFFMKT_SAMETECH has 3 events
# ADLR_TREATING_SAMEMKT_SAMETECH has no events
# ADLR_TREATING_SAMEMKT_DIFFTECH has 96 events
# ADLR_TREATING_DIFFMKT_SAMETECH has 7 events
# ADLR_TREATED_SAMEMKT_SAMETECH has 3 events
# ADLR_TREATED_SAMEMKT_DIFFTECH has 176 events
# ADLR_TREATED_DIFFMKT_SAMETECH has 14 events
# ADMA_TREATING_SAMEMKT_SAMETECH has no events
# ADMA_TREATING_SAMEMKT_DIFFTECH has no events
# ADMA_TREATING_DIFFMKT_SAMETECH has no events
# ADMA_TREATED_SAMEMKT_SAMETECH has no events
# ADMA_TREATED_SAMEMKT_DIFFTECH has no events
# ADMA_TREATED_DIFFMKT_SAMETECH has 1 events
# ADMP_TREATING_SAMEMKT_SAMETECH has no events
# ADMP_TREATING_SAMEMKT_DIFFTECH has no events
# ADMP_TREATING_DIFFMKT_SAMETECH has no events
# ADMP_TREATED_SAMEMKT_SAMETECH has no events
# ADMP_TREATED_SAMEMKT_DIFFTECH has 134 events
# ADMP_TREATED_DIFFMKT_SAMETECH has 5 events
# ADMS_TREATING_SAMEMKT_SAMETECH has no events
# ADMS_TREATING_SAMEMKT_DIFFTECH has no events
# ADMS_TREATING_DIFFMKT_SAMETECH has no events
# ADMS_TREATED_SAMEMKT_SAMETECH has no events
# ADMS_TREATED_SAMEMKT_DIFFTECH has 16 events
# ADMS_TREATED_DIFFMKT_SAMETECH has no events
# ADRO_TREATING_SAMEMKT_SAMETECH has no events
# ADRO_TREATING_SAMEMKT_DIFFTECH has no events
# ADRO_TREATING_DIFFMKT_SAMETECH has no events
# ADRO_TREATED_SAMEMKT_SAMETECH has no events
# ADRO_TREATED_SAMEMKT_DIFFTECH has 44 events
# ADRO_TREATED_DIFFMKT_SAMETECH has no events
# ADSK_TREATING_SAMEMKT_SAMETECH has no events
# ADSK_TREATING_SAMEMKT_DIFFTECH has no events
# ADSK_TREATING_DIFFMKT_SAMETECH has no events
# ADSK_TREATED_SAMEMKT_SAMETECH has no events
# ADSK_TREATED_SAMEMKT_DIFFTECH has no events
# ADSK_TREATED_DIFFMKT_SAMETECH has no events
# ADXS_TREATING_SAMEMKT_SAMETECH has no events
# ADXS_TREATING_SAMEMKT_DIFFTECH has no events
# ADXS_TREATING_DIFFMKT_SAMETECH has no events
# ADXS_TREATED_SAMEMKT_SAMETECH has no events
# ADXS_TREATED_SAMEMKT_DIFFTECH has 62 events
# ADXS_TREATED_DIFFMKT_SAMETECH has no events
# AEGR_TREATING_SAMEMKT_SAMETECH has no events
# AEGR_TREATING_SAMEMKT_DIFFTECH has no events
# AEGR_TREATING_DIFFMKT_SAMETECH has no events
# AEGR_TREATED_SAMEMKT_SAMETECH has no events
# AEGR_TREATED_SAMEMKT_DIFFTECH has 14 events
# AEGR_TREATED_DIFFMKT_SAMETECH has no events
# AEN_TREATING_SAMEMKT_SAMETECH has no events
# AEN_TREATING_SAMEMKT_DIFFTECH has no events
# AEN_TREATING_DIFFMKT_SAMETECH has no events
# AEN_TREATED_SAMEMKT_SAMETECH has no events
# AEN_TREATED_SAMEMKT_DIFFTECH has no events
# AEN_TREATED_DIFFMKT_SAMETECH has no events
# AERI_TREATING_SAMEMKT_SAMETECH has 12 events
# AERI_TREATING_SAMEMKT_DIFFTECH has 102 events
# AERI_TREATING_DIFFMKT_SAMETECH has 13 events
# AERI_TREATED_SAMEMKT_SAMETECH has 5 events
# AERI_TREATED_SAMEMKT_DIFFTECH has 32 events
# AERI_TREATED_DIFFMKT_SAMETECH has 4 events
# AEZ_TREATING_SAMEMKT_SAMETECH has 5 events
# AEZ_TREATING_SAMEMKT_DIFFTECH has 2557 events
# AEZ_TREATING_DIFFMKT_SAMETECH has 139 events
# AEZ_TREATED_SAMEMKT_SAMETECH has 2 events
# AEZ_TREATED_SAMEMKT_DIFFTECH has 753 events
# AEZ_TREATED_DIFFMKT_SAMETECH has 41 events
# AFFY_TREATING_SAMEMKT_SAMETECH has no events
# AFFY_TREATING_SAMEMKT_DIFFTECH has no events
# AFFY_TREATING_DIFFMKT_SAMETECH has no events
# AFFY_TREATED_SAMEMKT_SAMETECH has no events
# AFFY_TREATED_SAMEMKT_DIFFTECH has 8 events
# AFFY_TREATED_DIFFMKT_SAMETECH has no events
# AGEN_TREATING_SAMEMKT_SAMETECH has 1 events
# AGEN_TREATING_SAMEMKT_DIFFTECH has 568 events
# AGEN_TREATING_DIFFMKT_SAMETECH has 1 events
# AGEN_TREATED_SAMEMKT_SAMETECH has no events
# AGEN_TREATED_SAMEMKT_DIFFTECH has 648 events
# AGEN_TREATED_DIFFMKT_SAMETECH has 1 events
# AGN_TREATING_SAMEMKT_SAMETECH has no events
# AGN_TREATING_SAMEMKT_DIFFTECH has 40 events
# AGN_TREATING_DIFFMKT_SAMETECH has 45 events
# AGN_TREATED_SAMEMKT_SAMETECH has no events
# AGN_TREATED_SAMEMKT_DIFFTECH has 288 events
# AGN_TREATED_DIFFMKT_SAMETECH has 15 events
# AGRX_TREATING_SAMEMKT_SAMETECH has no events
# AGRX_TREATING_SAMEMKT_DIFFTECH has no events
# AGRX_TREATING_DIFFMKT_SAMETECH has no events
# AGRX_TREATED_SAMEMKT_SAMETECH has no events
# AGRX_TREATED_SAMEMKT_DIFFTECH has 13 events
# AGRX_TREATED_DIFFMKT_SAMETECH has 1 events
# AGX_TREATING_SAMEMKT_SAMETECH has 3 events
# AGX_TREATING_SAMEMKT_DIFFTECH has 1301 events
# AGX_TREATING_DIFFMKT_SAMETECH has 50 events
# AGX_TREATED_SAMEMKT_SAMETECH has 2 events
# AGX_TREATED_SAMEMKT_DIFFTECH has 327 events
# AGX_TREATED_DIFFMKT_SAMETECH has 13 events
# AHM_TREATING_SAMEMKT_SAMETECH has no events
# AHM_TREATING_SAMEMKT_DIFFTECH has no events
# AHM_TREATING_DIFFMKT_SAMETECH has no events
# AHM_TREATED_SAMEMKT_SAMETECH has 1 events
# AHM_TREATED_SAMEMKT_DIFFTECH has 156 events
# AHM_TREATED_DIFFMKT_SAMETECH has 7 events
# AIS_TREATING_SAMEMKT_SAMETECH has no events
# AIS_TREATING_SAMEMKT_DIFFTECH has no events
# AIS_TREATING_DIFFMKT_SAMETECH has no events
# AIS_TREATED_SAMEMKT_SAMETECH has no events
# AIS_TREATED_SAMEMKT_DIFFTECH has no events
# AIS_TREATED_DIFFMKT_SAMETECH has no events
# AKBA_TREATING_SAMEMKT_SAMETECH has no events
# AKBA_TREATING_SAMEMKT_DIFFTECH has no events
# AKBA_TREATING_DIFFMKT_SAMETECH has no events
# AKBA_TREATED_SAMEMKT_SAMETECH has no events
# AKBA_TREATED_SAMEMKT_DIFFTECH has 24 events
# AKBA_TREATED_DIFFMKT_SAMETECH has no events
# AKTX_TREATING_SAMEMKT_SAMETECH has no events
# AKTX_TREATING_SAMEMKT_DIFFTECH has no events
# AKTX_TREATING_DIFFMKT_SAMETECH has no events
# AKTX_TREATED_SAMEMKT_SAMETECH has no events
# AKTX_TREATED_SAMEMKT_DIFFTECH has no events
# AKTX_TREATED_DIFFMKT_SAMETECH has no events
# ALIM_TREATING_SAMEMKT_SAMETECH has no events
# ALIM_TREATING_SAMEMKT_DIFFTECH has no events
# ALIM_TREATING_DIFFMKT_SAMETECH has no events
# ALIM_TREATED_SAMEMKT_SAMETECH has no events
# ALIM_TREATED_SAMEMKT_DIFFTECH has 4 events
# ALIM_TREATED_DIFFMKT_SAMETECH has 4 events
# ALKS_TREATING_SAMEMKT_SAMETECH has no events
# ALKS_TREATING_SAMEMKT_DIFFTECH has 69 events
# ALKS_TREATING_DIFFMKT_SAMETECH has 1 events
# ALKS_TREATED_SAMEMKT_SAMETECH has 2 events
# ALKS_TREATED_SAMEMKT_DIFFTECH has 217 events
# ALKS_TREATED_DIFFMKT_SAMETECH has 14 events
# ALNY_TREATING_SAMEMKT_SAMETECH has no events
# ALNY_TREATING_SAMEMKT_DIFFTECH has no events
# ALNY_TREATING_DIFFMKT_SAMETECH has no events
# ALNY_TREATED_SAMEMKT_SAMETECH has no events
# ALNY_TREATED_SAMEMKT_DIFFTECH has 54 events
# ALNY_TREATED_DIFFMKT_SAMETECH has no events
# ALSE_TREATING_SAMEMKT_SAMETECH has no events
# ALSE_TREATING_SAMEMKT_DIFFTECH has no events
# ALSE_TREATING_DIFFMKT_SAMETECH has no events
# ALSE_TREATED_SAMEMKT_SAMETECH has no events
# ALSE_TREATED_SAMEMKT_DIFFTECH has 5 events
# ALSE_TREATED_DIFFMKT_SAMETECH has 6 events
# ALT_TREATING_SAMEMKT_SAMETECH has no events
# ALT_TREATING_SAMEMKT_DIFFTECH has 83 events
# ALT_TREATING_DIFFMKT_SAMETECH has 4 events
# ALT_TREATED_SAMEMKT_SAMETECH has no events
# ALT_TREATED_SAMEMKT_DIFFTECH has 4 events
# ALT_TREATED_DIFFMKT_SAMETECH has 1 events
# ALXA_TREATING_SAMEMKT_SAMETECH has no events
# ALXA_TREATING_SAMEMKT_DIFFTECH has no events
# ALXA_TREATING_DIFFMKT_SAMETECH has no events
# ALXA_TREATED_SAMEMKT_SAMETECH has no events
# ALXA_TREATED_SAMEMKT_DIFFTECH has 34 events
# ALXA_TREATED_DIFFMKT_SAMETECH has 8 events
# ALXN_TREATING_SAMEMKT_SAMETECH has no events
# ALXN_TREATING_SAMEMKT_DIFFTECH has no events
# ALXN_TREATING_DIFFMKT_SAMETECH has no events
# ALXN_TREATED_SAMEMKT_SAMETECH has no events
# ALXN_TREATED_SAMEMKT_DIFFTECH has 125 events
# ALXN_TREATED_DIFFMKT_SAMETECH has no events
# AMAG_TREATING_SAMEMKT_SAMETECH has no events
# AMAG_TREATING_SAMEMKT_DIFFTECH has 10 events
# AMAG_TREATING_DIFFMKT_SAMETECH has no events
# AMAG_TREATED_SAMEMKT_SAMETECH has no events
# AMAG_TREATED_SAMEMKT_DIFFTECH has 14 events
# AMAG_TREATED_DIFFMKT_SAMETECH has no events
# AMB_TREATING_SAMEMKT_SAMETECH has no events
# AMB_TREATING_SAMEMKT_DIFFTECH has 99 events
# AMB_TREATING_DIFFMKT_SAMETECH has 7 events
# AMB_TREATED_SAMEMKT_SAMETECH has 1 events
# AMB_TREATED_SAMEMKT_DIFFTECH has 78 events
# AMB_TREATED_DIFFMKT_SAMETECH has 7 events
# AMGN_TREATING_SAMEMKT_SAMETECH has 39 events
# AMGN_TREATING_SAMEMKT_DIFFTECH has 7104 events
# AMGN_TREATING_DIFFMKT_SAMETECH has 443 events
# AMGN_TREATED_SAMEMKT_SAMETECH has 68 events
# AMGN_TREATED_SAMEMKT_DIFFTECH has 5875 events
# AMGN_TREATED_DIFFMKT_SAMETECH has 909 events
# AMPE_TREATING_SAMEMKT_SAMETECH has no events
# AMPE_TREATING_SAMEMKT_DIFFTECH has no events
# AMPE_TREATING_DIFFMKT_SAMETECH has no events
# AMPE_TREATED_SAMEMKT_SAMETECH has 1 events
# AMPE_TREATED_SAMEMKT_DIFFTECH has 77 events
# AMPE_TREATED_DIFFMKT_SAMETECH has 4 events
# AMRN_TREATING_SAMEMKT_SAMETECH has no events
# AMRN_TREATING_SAMEMKT_DIFFTECH has 284 events
# AMRN_TREATING_DIFFMKT_SAMETECH has 14 events
# AMRN_TREATED_SAMEMKT_SAMETECH has no events
# AMRN_TREATED_SAMEMKT_DIFFTECH has 193 events
# AMRN_TREATED_DIFFMKT_SAMETECH has 18 events
# ANAC_TREATING_SAMEMKT_SAMETECH has no events
# ANAC_TREATING_SAMEMKT_DIFFTECH has 76 events
# ANAC_TREATING_DIFFMKT_SAMETECH has no events
# ANAC_TREATED_SAMEMKT_SAMETECH has no events
# ANAC_TREATED_SAMEMKT_DIFFTECH has 79 events
# ANAC_TREATED_DIFFMKT_SAMETECH has 16 events
# ANIP_TREATING_SAMEMKT_SAMETECH has no events
# ANIP_TREATING_SAMEMKT_DIFFTECH has 215 events
# ANIP_TREATING_DIFFMKT_SAMETECH has 1 events
# ANIP_TREATED_SAMEMKT_SAMETECH has no events
# ANIP_TREATED_SAMEMKT_DIFFTECH has 508 events
# ANIP_TREATED_DIFFMKT_SAMETECH has 22 events
# ANTH_TREATING_SAMEMKT_SAMETECH has no events
# ANTH_TREATING_SAMEMKT_DIFFTECH has 13 events
# ANTH_TREATING_DIFFMKT_SAMETECH has 8 events
# ANTH_TREATED_SAMEMKT_SAMETECH has no events
# ANTH_TREATED_SAMEMKT_DIFFTECH has 2 events
# ANTH_TREATED_DIFFMKT_SAMETECH has 5 events
# ANX_TREATING_SAMEMKT_SAMETECH has no events
# ANX_TREATING_SAMEMKT_DIFFTECH has no events
# ANX_TREATING_DIFFMKT_SAMETECH has no events
# ANX_TREATED_SAMEMKT_SAMETECH has no events
# ANX_TREATED_SAMEMKT_DIFFTECH has no events
# ANX_TREATED_DIFFMKT_SAMETECH has no events
# APHB_TREATING_SAMEMKT_SAMETECH has 4 events
# APHB_TREATING_SAMEMKT_DIFFTECH has 36 events
# APHB_TREATING_DIFFMKT_SAMETECH has 1 events
# APHB_TREATED_SAMEMKT_SAMETECH has no events
# APHB_TREATED_SAMEMKT_DIFFTECH has 262 events
# APHB_TREATED_DIFFMKT_SAMETECH has 6 events
# APPA_TREATING_SAMEMKT_SAMETECH has no events
# APPA_TREATING_SAMEMKT_DIFFTECH has no events
# APPA_TREATING_DIFFMKT_SAMETECH has no events
# APPA_TREATED_SAMEMKT_SAMETECH has no events
# APPA_TREATED_SAMEMKT_DIFFTECH has no events
# APPA_TREATED_DIFFMKT_SAMETECH has no events
# APRI_TREATING_SAMEMKT_SAMETECH has no events
# APRI_TREATING_SAMEMKT_DIFFTECH has no events
# APRI_TREATING_DIFFMKT_SAMETECH has no events
# APRI_TREATED_SAMEMKT_SAMETECH has no events
# APRI_TREATED_SAMEMKT_DIFFTECH has 11 events
# APRI_TREATED_DIFFMKT_SAMETECH has 1 events
# AQXP_TREATING_SAMEMKT_SAMETECH has no events
# AQXP_TREATING_SAMEMKT_DIFFTECH has no events
# AQXP_TREATING_DIFFMKT_SAMETECH has no events
# AQXP_TREATED_SAMEMKT_SAMETECH has no events
# AQXP_TREATED_SAMEMKT_DIFFTECH has 13 events
# AQXP_TREATED_DIFFMKT_SAMETECH has no events
# ARCP_TREATING_SAMEMKT_SAMETECH has no events
# ARCP_TREATING_SAMEMKT_DIFFTECH has no events
# ARCP_TREATING_DIFFMKT_SAMETECH has no events
# ARCP_TREATED_SAMEMKT_SAMETECH has no events
# ARCP_TREATED_SAMEMKT_DIFFTECH has no events
# ARCP_TREATED_DIFFMKT_SAMETECH has no events
# ARDM_TREATING_SAMEMKT_SAMETECH has no events
# ARDM_TREATING_SAMEMKT_DIFFTECH has 52 events
# ARDM_TREATING_DIFFMKT_SAMETECH has no events
# ARDM_TREATED_SAMEMKT_SAMETECH has 1 events
# ARDM_TREATED_SAMEMKT_DIFFTECH has 124 events
# ARDM_TREATED_DIFFMKT_SAMETECH has 11 events
# ARDX_TREATING_SAMEMKT_SAMETECH has no events
# ARDX_TREATING_SAMEMKT_DIFFTECH has no events
# ARDX_TREATING_DIFFMKT_SAMETECH has no events
# ARDX_TREATED_SAMEMKT_SAMETECH has no events
# ARDX_TREATED_SAMEMKT_DIFFTECH has 1 events
# ARDX_TREATED_DIFFMKT_SAMETECH has no events
# ARGS_TREATING_SAMEMKT_SAMETECH has no events
# ARGS_TREATING_SAMEMKT_DIFFTECH has no events
# ARGS_TREATING_DIFFMKT_SAMETECH has no events
# ARGS_TREATED_SAMEMKT_SAMETECH has no events
# ARGS_TREATED_SAMEMKT_DIFFTECH has 63 events
# ARGS_TREATED_DIFFMKT_SAMETECH has no events
# ARIA_TREATING_SAMEMKT_SAMETECH has no events
# ARIA_TREATING_SAMEMKT_DIFFTECH has no events
# ARIA_TREATING_DIFFMKT_SAMETECH has no events
# ARIA_TREATED_SAMEMKT_SAMETECH has 6 events
# ARIA_TREATED_SAMEMKT_DIFFTECH has 546 events
# ARIA_TREATED_DIFFMKT_SAMETECH has 88 events
# ARNA_TREATING_SAMEMKT_SAMETECH has no events
# ARNA_TREATING_SAMEMKT_DIFFTECH has 55 events
# ARNA_TREATING_DIFFMKT_SAMETECH has no events
# ARNA_TREATED_SAMEMKT_SAMETECH has no events
# ARNA_TREATED_SAMEMKT_DIFFTECH has 75 events
# ARNA_TREATED_DIFFMKT_SAMETECH has 3 events
# ARQL_TREATING_SAMEMKT_SAMETECH has 1 events
# ARQL_TREATING_SAMEMKT_DIFFTECH has 319 events
# ARQL_TREATING_DIFFMKT_SAMETECH has 3 events
# ARQL_TREATED_SAMEMKT_SAMETECH has 1 events
# ARQL_TREATED_SAMEMKT_DIFFTECH has 567 events
# ARQL_TREATED_DIFFMKT_SAMETECH has 24 events
# ARRY_TREATING_SAMEMKT_SAMETECH has no events
# ARRY_TREATING_SAMEMKT_DIFFTECH has 26 events
# ARRY_TREATING_DIFFMKT_SAMETECH has 58 events
# ARRY_TREATED_SAMEMKT_SAMETECH has 3 events
# ARRY_TREATED_SAMEMKT_DIFFTECH has 494 events
# ARRY_TREATED_DIFFMKT_SAMETECH has 59 events
# ARWR_TREATING_SAMEMKT_SAMETECH has no events
# ARWR_TREATING_SAMEMKT_DIFFTECH has no events
# ARWR_TREATING_DIFFMKT_SAMETECH has no events
# ARWR_TREATED_SAMEMKT_SAMETECH has no events
# ARWR_TREATED_SAMEMKT_DIFFTECH has 84 events
# ARWR_TREATED_DIFFMKT_SAMETECH has 4 events
# ARYX_TREATING_SAMEMKT_SAMETECH has no events
# ARYX_TREATING_SAMEMKT_DIFFTECH has no events
# ARYX_TREATING_DIFFMKT_SAMETECH has no events
# ARYX_TREATED_SAMEMKT_SAMETECH has 2 events
# ARYX_TREATED_SAMEMKT_DIFFTECH has 26 events
# ARYX_TREATED_DIFFMKT_SAMETECH has 1 events
# ASND_TREATING_SAMEMKT_SAMETECH has no events
# ASND_TREATING_SAMEMKT_DIFFTECH has no events
# ASND_TREATING_DIFFMKT_SAMETECH has no events
# ASND_TREATED_SAMEMKT_SAMETECH has no events
# ASND_TREATED_SAMEMKT_DIFFTECH has 4 events
# ASND_TREATED_DIFFMKT_SAMETECH has no events
# ATHX_TREATING_SAMEMKT_SAMETECH has no events
# ATHX_TREATING_SAMEMKT_DIFFTECH has no events
# ATHX_TREATING_DIFFMKT_SAMETECH has no events
# ATHX_TREATED_SAMEMKT_SAMETECH has no events
# ATHX_TREATED_SAMEMKT_DIFFTECH has 12 events
# ATHX_TREATED_DIFFMKT_SAMETECH has no events
# ATI_TREATING_SAMEMKT_SAMETECH has no events
# ATI_TREATING_SAMEMKT_DIFFTECH has no events
# ATI_TREATING_DIFFMKT_SAMETECH has no events
# ATI_TREATED_SAMEMKT_SAMETECH has no events
# ATI_TREATED_SAMEMKT_DIFFTECH has no events
# ATI_TREATED_DIFFMKT_SAMETECH has no events
# ATNM_TREATING_SAMEMKT_SAMETECH has no events
# ATNM_TREATING_SAMEMKT_DIFFTECH has no events
# ATNM_TREATING_DIFFMKT_SAMETECH has no events
# ATNM_TREATED_SAMEMKT_SAMETECH has no events
# ATNM_TREATED_SAMEMKT_DIFFTECH has 27 events
# ATNM_TREATED_DIFFMKT_SAMETECH has no events
# ATRS_TREATING_SAMEMKT_SAMETECH has no events
# ATRS_TREATING_SAMEMKT_DIFFTECH has no events
# ATRS_TREATING_DIFFMKT_SAMETECH has no events
# ATRS_TREATED_SAMEMKT_SAMETECH has no events
# ATRS_TREATED_SAMEMKT_DIFFTECH has 20 events
# ATRS_TREATED_DIFFMKT_SAMETECH has 4 events
# AVAN_TREATING_SAMEMKT_SAMETECH has no events
# AVAN_TREATING_SAMEMKT_DIFFTECH has no events
# AVAN_TREATING_DIFFMKT_SAMETECH has no events
# AVAN_TREATED_SAMEMKT_SAMETECH has no events
# AVAN_TREATED_SAMEMKT_DIFFTECH has no events
# AVAN_TREATED_DIFFMKT_SAMETECH has no events
# AVII_TREATING_SAMEMKT_SAMETECH has no events
# AVII_TREATING_SAMEMKT_DIFFTECH has no events
# AVII_TREATING_DIFFMKT_SAMETECH has no events
# AVII_TREATED_SAMEMKT_SAMETECH has no events
# AVII_TREATED_SAMEMKT_DIFFTECH has no events
# AVII_TREATED_DIFFMKT_SAMETECH has no events
# AZN_TREATING_SAMEMKT_SAMETECH has 206 events
# AZN_TREATING_SAMEMKT_DIFFTECH has 16804 events
# AZN_TREATING_DIFFMKT_SAMETECH has 2377 events
# AZN_TREATED_SAMEMKT_SAMETECH has 82 events
# AZN_TREATED_SAMEMKT_DIFFTECH has 7127 events
# AZN_TREATED_DIFFMKT_SAMETECH has 1449 events
# BAX_TREATING_SAMEMKT_SAMETECH has 12 events
# BAX_TREATING_SAMEMKT_DIFFTECH has 157 events
# BAX_TREATING_DIFFMKT_SAMETECH has 14 events
# BAX_TREATED_SAMEMKT_SAMETECH has 1 events
# BAX_TREATED_SAMEMKT_DIFFTECH has 201 events
# BAX_TREATED_DIFFMKT_SAMETECH has 15 events
# BAYN_TREATING_SAMEMKT_SAMETECH has 22 events
# BAYN_TREATING_SAMEMKT_DIFFTECH has 3249 events
# BAYN_TREATING_DIFFMKT_SAMETECH has 1070 events
# BAYN_TREATED_SAMEMKT_SAMETECH has 69 events
# BAYN_TREATED_SAMEMKT_DIFFTECH has 5957 events
# BAYN_TREATED_DIFFMKT_SAMETECH has 1326 events
# BCLI_TREATING_SAMEMKT_SAMETECH has no events
# BCLI_TREATING_SAMEMKT_DIFFTECH has no events
# BCLI_TREATING_DIFFMKT_SAMETECH has no events
# BCLI_TREATED_SAMEMKT_SAMETECH has no events
# BCLI_TREATED_SAMEMKT_DIFFTECH has 10 events
# BCLI_TREATED_DIFFMKT_SAMETECH has no events
# BCRX_TREATING_SAMEMKT_SAMETECH has no events
# BCRX_TREATING_SAMEMKT_DIFFTECH has 159 events
# BCRX_TREATING_DIFFMKT_SAMETECH has 11 events
# BCRX_TREATED_SAMEMKT_SAMETECH has no events
# BCRX_TREATED_SAMEMKT_DIFFTECH has 75 events
# BCRX_TREATED_DIFFMKT_SAMETECH has 5 events
# BDSI_TREATING_SAMEMKT_SAMETECH has no events
# BDSI_TREATING_SAMEMKT_DIFFTECH has no events
# BDSI_TREATING_DIFFMKT_SAMETECH has no events
# BDSI_TREATED_SAMEMKT_SAMETECH has no events
# BDSI_TREATED_SAMEMKT_DIFFTECH has 41 events
# BDSI_TREATED_DIFFMKT_SAMETECH has 3 events
# BEAM_TREATING_SAMEMKT_SAMETECH has no events
# BEAM_TREATING_SAMEMKT_DIFFTECH has no events
# BEAM_TREATING_DIFFMKT_SAMETECH has no events
# BEAM_TREATED_SAMEMKT_SAMETECH has no events
# BEAM_TREATED_SAMEMKT_DIFFTECH has no events
# BEAM_TREATED_DIFFMKT_SAMETECH has no events
# BEC_TREATING_SAMEMKT_SAMETECH has no events
# BEC_TREATING_SAMEMKT_DIFFTECH has no events
# BEC_TREATING_DIFFMKT_SAMETECH has no events
# BEC_TREATED_SAMEMKT_SAMETECH has no events
# BEC_TREATED_SAMEMKT_DIFFTECH has 19 events
# BEC_TREATED_DIFFMKT_SAMETECH has 3 events
# BIOC_TREATING_SAMEMKT_SAMETECH has no events
# BIOC_TREATING_SAMEMKT_DIFFTECH has no events
# BIOC_TREATING_DIFFMKT_SAMETECH has no events
# BIOC_TREATED_SAMEMKT_SAMETECH has no events
# BIOC_TREATED_SAMEMKT_DIFFTECH has no events
# BIOC_TREATED_DIFFMKT_SAMETECH has no events
# BIOD_TREATING_SAMEMKT_SAMETECH has no events
# BIOD_TREATING_SAMEMKT_DIFFTECH has no events
# BIOD_TREATING_DIFFMKT_SAMETECH has no events
# BIOD_TREATED_SAMEMKT_SAMETECH has no events
# BIOD_TREATED_SAMEMKT_DIFFTECH has 2 events
# BIOD_TREATED_DIFFMKT_SAMETECH has no events
# BIOM_TREATING_SAMEMKT_SAMETECH has no events
# BIOM_TREATING_SAMEMKT_DIFFTECH has no events
# BIOM_TREATING_DIFFMKT_SAMETECH has no events
# BIOM_TREATED_SAMEMKT_SAMETECH has no events
# BIOM_TREATED_SAMEMKT_DIFFTECH has no events
# BIOM_TREATED_DIFFMKT_SAMETECH has no events
# BIT_TREATING_SAMEMKT_SAMETECH has no events
# BIT_TREATING_SAMEMKT_DIFFTECH has no events
# BIT_TREATING_DIFFMKT_SAMETECH has no events
# BIT_TREATED_SAMEMKT_SAMETECH has no events
# BIT_TREATED_SAMEMKT_DIFFTECH has 7 events
# BIT_TREATED_DIFFMKT_SAMETECH has 4 events
# BITI_TREATING_SAMEMKT_SAMETECH has no events
# BITI_TREATING_SAMEMKT_DIFFTECH has no events
# BITI_TREATING_DIFFMKT_SAMETECH has no events
# BITI_TREATED_SAMEMKT_SAMETECH has no events
# BITI_TREATED_SAMEMKT_DIFFTECH has no events
# BITI_TREATED_DIFFMKT_SAMETECH has no events
# BLCM_TREATING_SAMEMKT_SAMETECH has no events
# BLCM_TREATING_SAMEMKT_DIFFTECH has no events
# BLCM_TREATING_DIFFMKT_SAMETECH has no events
# BLCM_TREATED_SAMEMKT_SAMETECH has no events
# BLCM_TREATED_SAMEMKT_DIFFTECH has 44 events
# BLCM_TREATED_DIFFMKT_SAMETECH has no events
# BLSI_TREATING_SAMEMKT_SAMETECH has no events
# BLSI_TREATING_SAMEMKT_DIFFTECH has no events
# BLSI_TREATING_DIFFMKT_SAMETECH has no events
# BLSI_TREATED_SAMEMKT_SAMETECH has no events
# BLSI_TREATED_SAMEMKT_DIFFTECH has no events
# BLSI_TREATED_DIFFMKT_SAMETECH has no events
# BLT_TREATING_SAMEMKT_SAMETECH has no events
# BLT_TREATING_SAMEMKT_DIFFTECH has no events
# BLT_TREATING_DIFFMKT_SAMETECH has no events
# BLT_TREATED_SAMEMKT_SAMETECH has no events
# BLT_TREATED_SAMEMKT_DIFFTECH has 56 events
# BLT_TREATED_DIFFMKT_SAMETECH has 2 events
# BLU_TREATING_SAMEMKT_SAMETECH has no events
# BLU_TREATING_SAMEMKT_DIFFTECH has 218 events
# BLU_TREATING_DIFFMKT_SAMETECH has no events
# BLU_TREATED_SAMEMKT_SAMETECH has no events
# BLU_TREATED_SAMEMKT_DIFFTECH has 151 events
# BLU_TREATED_DIFFMKT_SAMETECH has no events
# BMRN_TREATING_SAMEMKT_SAMETECH has no events
# BMRN_TREATING_SAMEMKT_DIFFTECH has 377 events
# BMRN_TREATING_DIFFMKT_SAMETECH has 16 events
# BMRN_TREATED_SAMEMKT_SAMETECH has no events
# BMRN_TREATED_SAMEMKT_DIFFTECH has 131 events
# BMRN_TREATED_DIFFMKT_SAMETECH has 19 events
# BMY_TREATING_SAMEMKT_SAMETECH has 65 events
# BMY_TREATING_SAMEMKT_DIFFTECH has 8290 events
# BMY_TREATING_DIFFMKT_SAMETECH has 646 events
# BMY_TREATED_SAMEMKT_SAMETECH has 101 events
# BMY_TREATED_SAMEMKT_DIFFTECH has 10513 events
# BMY_TREATED_DIFFMKT_SAMETECH has 1057 events
# BNO_TREATING_SAMEMKT_SAMETECH has no events
# BNO_TREATING_SAMEMKT_DIFFTECH has no events
# BNO_TREATING_DIFFMKT_SAMETECH has no events
# BNO_TREATED_SAMEMKT_SAMETECH has no events
# BNO_TREATED_SAMEMKT_DIFFTECH has 78 events
# BNO_TREATED_DIFFMKT_SAMETECH has 21 events
# BOTA_TREATING_SAMEMKT_SAMETECH has no events
# BOTA_TREATING_SAMEMKT_DIFFTECH has no events
# BOTA_TREATING_DIFFMKT_SAMETECH has no events
# BOTA_TREATED_SAMEMKT_SAMETECH has no events
# BOTA_TREATED_SAMEMKT_DIFFTECH has 6 events
# BOTA_TREATED_DIFFMKT_SAMETECH has no events
# BPA_TREATING_SAMEMKT_SAMETECH has no events
# BPA_TREATING_SAMEMKT_DIFFTECH has no events
# BPA_TREATING_DIFFMKT_SAMETECH has no events
# BPA_TREATED_SAMEMKT_SAMETECH has no events
# BPA_TREATED_SAMEMKT_DIFFTECH has no events
# BPA_TREATED_DIFFMKT_SAMETECH has no events
# BPAX_TREATING_SAMEMKT_SAMETECH has no events
# BPAX_TREATING_SAMEMKT_DIFFTECH has no events
# BPAX_TREATING_DIFFMKT_SAMETECH has no events
# BPAX_TREATED_SAMEMKT_SAMETECH has no events
# BPAX_TREATED_SAMEMKT_DIFFTECH has no events
# BPAX_TREATED_DIFFMKT_SAMETECH has no events
# BSAC_TREATING_SAMEMKT_SAMETECH has no events
# BSAC_TREATING_SAMEMKT_DIFFTECH has no events
# BSAC_TREATING_DIFFMKT_SAMETECH has no events
# BSAC_TREATED_SAMEMKT_SAMETECH has no events
# BSAC_TREATED_SAMEMKT_DIFFTECH has no events
# BSAC_TREATED_DIFFMKT_SAMETECH has no events
# BSTC_TREATING_SAMEMKT_SAMETECH has no events
# BSTC_TREATING_SAMEMKT_DIFFTECH has no events
# BSTC_TREATING_DIFFMKT_SAMETECH has no events
# BSTC_TREATED_SAMEMKT_SAMETECH has no events
# BSTC_TREATED_SAMEMKT_DIFFTECH has 2 events
# BSTC_TREATED_DIFFMKT_SAMETECH has no events
# BTG_TREATING_SAMEMKT_SAMETECH has 1 events
# BTG_TREATING_SAMEMKT_DIFFTECH has 142 events
# BTG_TREATING_DIFFMKT_SAMETECH has 26 events
# BTG_TREATED_SAMEMKT_SAMETECH has 2 events
# BTG_TREATED_SAMEMKT_DIFFTECH has 192 events
# BTG_TREATED_DIFFMKT_SAMETECH has 15 events
# BTIM_TREATING_SAMEMKT_SAMETECH has no events
# BTIM_TREATING_SAMEMKT_DIFFTECH has no events
# BTIM_TREATING_DIFFMKT_SAMETECH has no events
# BTIM_TREATED_SAMEMKT_SAMETECH has no events
# BTIM_TREATED_SAMEMKT_DIFFTECH has no events
# BTIM_TREATED_DIFFMKT_SAMETECH has no events
# BTX_TREATING_SAMEMKT_SAMETECH has no events
# BTX_TREATING_SAMEMKT_DIFFTECH has 234 events
# BTX_TREATING_DIFFMKT_SAMETECH has no events
# BTX_TREATED_SAMEMKT_SAMETECH has no events
# BTX_TREATED_SAMEMKT_DIFFTECH has 4 events
# BTX_TREATED_DIFFMKT_SAMETECH has no events
# BVF_TREATING_SAMEMKT_SAMETECH has no events
# BVF_TREATING_SAMEMKT_DIFFTECH has no events
# BVF_TREATING_DIFFMKT_SAMETECH has no events
# BVF_TREATED_SAMEMKT_SAMETECH has no events
# BVF_TREATED_SAMEMKT_DIFFTECH has no events
# BVF_TREATED_DIFFMKT_SAMETECH has no events
# CA_TREATING_SAMEMKT_SAMETECH has no events
# CA_TREATING_SAMEMKT_DIFFTECH has no events
# CA_TREATING_DIFFMKT_SAMETECH has no events
# CA_TREATED_SAMEMKT_SAMETECH has no events
# CA_TREATED_SAMEMKT_DIFFTECH has no events
# CA_TREATED_DIFFMKT_SAMETECH has no events
# CACH_TREATING_SAMEMKT_SAMETECH has no events
# CACH_TREATING_SAMEMKT_DIFFTECH has no events
# CACH_TREATING_DIFFMKT_SAMETECH has no events
# CACH_TREATED_SAMEMKT_SAMETECH has no events
# CACH_TREATED_SAMEMKT_DIFFTECH has no events
# CACH_TREATED_DIFFMKT_SAMETECH has no events
# CADE_TREATING_SAMEMKT_SAMETECH has no events
# CADE_TREATING_SAMEMKT_DIFFTECH has no events
# CADE_TREATING_DIFFMKT_SAMETECH has no events
# CADE_TREATED_SAMEMKT_SAMETECH has no events
# CADE_TREATED_SAMEMKT_DIFFTECH has no events
# CADE_TREATED_DIFFMKT_SAMETECH has no events
# CAPN_TREATING_SAMEMKT_SAMETECH has no events
# CAPN_TREATING_SAMEMKT_DIFFTECH has no events
# CAPN_TREATING_DIFFMKT_SAMETECH has no events
# CAPN_TREATED_SAMEMKT_SAMETECH has no events
# CAPN_TREATED_SAMEMKT_DIFFTECH has 13 events
# CAPN_TREATED_DIFFMKT_SAMETECH has no events
# CAPR_TREATING_SAMEMKT_SAMETECH has no events
# CAPR_TREATING_SAMEMKT_DIFFTECH has no events
# CAPR_TREATING_DIFFMKT_SAMETECH has no events
# CAPR_TREATED_SAMEMKT_SAMETECH has no events
# CAPR_TREATED_SAMEMKT_DIFFTECH has 48 events
# CAPR_TREATED_DIFFMKT_SAMETECH has no events
# CAPS_TREATING_SAMEMKT_SAMETECH has no events
# CAPS_TREATING_SAMEMKT_DIFFTECH has 40 events
# CAPS_TREATING_DIFFMKT_SAMETECH has no events
# CAPS_TREATED_SAMEMKT_SAMETECH has no events
# CAPS_TREATED_SAMEMKT_DIFFTECH has 45 events
# CAPS_TREATED_DIFFMKT_SAMETECH has no events
# CARA_TREATING_SAMEMKT_SAMETECH has no events
# CARA_TREATING_SAMEMKT_DIFFTECH has no events
# CARA_TREATING_DIFFMKT_SAMETECH has no events
# CARA_TREATED_SAMEMKT_SAMETECH has no events
# CARA_TREATED_SAMEMKT_DIFFTECH has 21 events
# CARA_TREATED_DIFFMKT_SAMETECH has 1 events
# CASI_TREATING_SAMEMKT_SAMETECH has 4 events
# CASI_TREATING_SAMEMKT_DIFFTECH has 1679 events
# CASI_TREATING_DIFFMKT_SAMETECH has 129 events
# CASI_TREATED_SAMEMKT_SAMETECH has 7 events
# CASI_TREATED_SAMEMKT_DIFFTECH has 712 events
# CASI_TREATED_DIFFMKT_SAMETECH has 97 events
# CBIO_TREATING_SAMEMKT_SAMETECH has 3 events
# CBIO_TREATING_SAMEMKT_DIFFTECH has 1080 events
# CBIO_TREATING_DIFFMKT_SAMETECH has 67 events
# CBIO_TREATED_SAMEMKT_SAMETECH has no events
# CBIO_TREATED_SAMEMKT_DIFFTECH has 327 events
# CBIO_TREATED_DIFFMKT_SAMETECH has 18 events
# CBMG_TREATING_SAMEMKT_SAMETECH has no events
# CBMG_TREATING_SAMEMKT_DIFFTECH has no events
# CBMG_TREATING_DIFFMKT_SAMETECH has no events
# CBMG_TREATED_SAMEMKT_SAMETECH has no events
# CBMG_TREATED_SAMEMKT_DIFFTECH has 2 events
# CBMG_TREATED_DIFFMKT_SAMETECH has no events
# CBRX_TREATING_SAMEMKT_SAMETECH has no events
# CBRX_TREATING_SAMEMKT_DIFFTECH has no events
# CBRX_TREATING_DIFFMKT_SAMETECH has no events
# CBRX_TREATED_SAMEMKT_SAMETECH has no events
# CBRX_TREATED_SAMEMKT_DIFFTECH has no events
# CBRX_TREATED_DIFFMKT_SAMETECH has no events
# CELG_TREATING_SAMEMKT_SAMETECH has 2 events
# CELG_TREATING_SAMEMKT_DIFFTECH has 447 events
# CELG_TREATING_DIFFMKT_SAMETECH has 37 events
# CELG_TREATED_SAMEMKT_SAMETECH has 6 events
# CELG_TREATED_SAMEMKT_DIFFTECH has 3270 events
# CELG_TREATED_DIFFMKT_SAMETECH has 238 events
# CFR_TREATING_SAMEMKT_SAMETECH has no events
# CFR_TREATING_SAMEMKT_DIFFTECH has no events
# CFR_TREATING_DIFFMKT_SAMETECH has no events
# CFR_TREATED_SAMEMKT_SAMETECH has no events
# CFR_TREATED_SAMEMKT_DIFFTECH has no events
# CFR_TREATED_DIFFMKT_SAMETECH has no events
# CGI_TREATING_SAMEMKT_SAMETECH has no events
# CGI_TREATING_SAMEMKT_DIFFTECH has no events
# CGI_TREATING_DIFFMKT_SAMETECH has no events
# CGI_TREATED_SAMEMKT_SAMETECH has no events
# CGI_TREATED_SAMEMKT_DIFFTECH has no events
# CGI_TREATED_DIFFMKT_SAMETECH has no events
# CHQ_TREATING_SAMEMKT_SAMETECH has no events
# CHQ_TREATING_SAMEMKT_DIFFTECH has 60 events
# CHQ_TREATING_DIFFMKT_SAMETECH has no events
# CHQ_TREATED_SAMEMKT_SAMETECH has no events
# CHQ_TREATED_SAMEMKT_DIFFTECH has 16 events
# CHQ_TREATED_DIFFMKT_SAMETECH has no events
# CLDN_TREATING_SAMEMKT_SAMETECH has no events
# CLDN_TREATING_SAMEMKT_DIFFTECH has no events
# CLDN_TREATING_DIFFMKT_SAMETECH has no events
# CLDN_TREATED_SAMEMKT_SAMETECH has no events
# CLDN_TREATED_SAMEMKT_DIFFTECH has 12 events
# CLDN_TREATED_DIFFMKT_SAMETECH has no events
# CLDX_TREATING_SAMEMKT_SAMETECH has 4 events
# CLDX_TREATING_SAMEMKT_DIFFTECH has 168 events
# CLDX_TREATING_DIFFMKT_SAMETECH has 7 events
# CLDX_TREATED_SAMEMKT_SAMETECH has 4 events
# CLDX_TREATED_SAMEMKT_DIFFTECH has 395 events
# CLDX_TREATED_DIFFMKT_SAMETECH has 14 events
# CLN_TREATING_SAMEMKT_SAMETECH has no events
# CLN_TREATING_SAMEMKT_DIFFTECH has no events
# CLN_TREATING_DIFFMKT_SAMETECH has no events
# CLN_TREATED_SAMEMKT_SAMETECH has no events
# CLN_TREATED_SAMEMKT_DIFFTECH has no events
# CLN_TREATED_DIFFMKT_SAMETECH has no events
# CLRB_TREATING_SAMEMKT_SAMETECH has no events
# CLRB_TREATING_SAMEMKT_DIFFTECH has no events
# CLRB_TREATING_DIFFMKT_SAMETECH has no events
# CLRB_TREATED_SAMEMKT_SAMETECH has no events
# CLRB_TREATED_SAMEMKT_DIFFTECH has 70 events
# CLRB_TREATED_DIFFMKT_SAMETECH has no events
# CLSN_TREATING_SAMEMKT_SAMETECH has no events
# CLSN_TREATING_SAMEMKT_DIFFTECH has no events
# CLSN_TREATING_DIFFMKT_SAMETECH has no events
# CLSN_TREATED_SAMEMKT_SAMETECH has no events
# CLSN_TREATED_SAMEMKT_DIFFTECH has 231 events
# CLSN_TREATED_DIFFMKT_SAMETECH has 6 events
# CLTX_TREATING_SAMEMKT_SAMETECH has no events
# CLTX_TREATING_SAMEMKT_DIFFTECH has no events
# CLTX_TREATING_DIFFMKT_SAMETECH has no events
# CLTX_TREATED_SAMEMKT_SAMETECH has no events
# CLTX_TREATED_SAMEMKT_DIFFTECH has 2 events
# CLTX_TREATED_DIFFMKT_SAMETECH has 11 events
# CNVX_TREATING_SAMEMKT_SAMETECH has no events
# CNVX_TREATING_SAMEMKT_DIFFTECH has no events
# CNVX_TREATING_DIFFMKT_SAMETECH has no events
# CNVX_TREATED_SAMEMKT_SAMETECH has no events
# CNVX_TREATED_SAMEMKT_DIFFTECH has no events
# CNVX_TREATED_DIFFMKT_SAMETECH has no events
# COB_TREATING_SAMEMKT_SAMETECH has no events
# COB_TREATING_SAMEMKT_DIFFTECH has no events
# COB_TREATING_DIFFMKT_SAMETECH has no events
# COB_TREATED_SAMEMKT_SAMETECH has no events
# COB_TREATED_SAMEMKT_DIFFTECH has no events
# COB_TREATED_DIFFMKT_SAMETECH has no events
# CPD_TREATING_SAMEMKT_SAMETECH has no events
# CPD_TREATING_SAMEMKT_DIFFTECH has no events
# CPD_TREATING_DIFFMKT_SAMETECH has no events
# CPD_TREATED_SAMEMKT_SAMETECH has no events
# CPD_TREATED_SAMEMKT_DIFFTECH has no events
# CPD_TREATED_DIFFMKT_SAMETECH has no events
# CPRX_TREATING_SAMEMKT_SAMETECH has 1 events
# CPRX_TREATING_SAMEMKT_DIFFTECH has 41 events
# CPRX_TREATING_DIFFMKT_SAMETECH has 2 events
# CPRX_TREATED_SAMEMKT_SAMETECH has no events
# CPRX_TREATED_SAMEMKT_DIFFTECH has 1 events
# CPRX_TREATED_DIFFMKT_SAMETECH has no events
# CPXX_TREATING_SAMEMKT_SAMETECH has no events
# CPXX_TREATING_SAMEMKT_DIFFTECH has no events
# CPXX_TREATING_DIFFMKT_SAMETECH has no events
# CPXX_TREATED_SAMEMKT_SAMETECH has no events
# CPXX_TREATED_SAMEMKT_DIFFTECH has 142 events
# CPXX_TREATED_DIFFMKT_SAMETECH has 12 events
# CRBP_TREATING_SAMEMKT_SAMETECH has no events
# CRBP_TREATING_SAMEMKT_DIFFTECH has no events
# CRBP_TREATING_DIFFMKT_SAMETECH has no events
# CRBP_TREATED_SAMEMKT_SAMETECH has no events
# CRBP_TREATED_SAMEMKT_DIFFTECH has 9 events
# CRBP_TREATED_DIFFMKT_SAMETECH has 1 events
# CRL_TREATING_SAMEMKT_SAMETECH has no events
# CRL_TREATING_SAMEMKT_DIFFTECH has no events
# CRL_TREATING_DIFFMKT_SAMETECH has no events
# CRL_TREATED_SAMEMKT_SAMETECH has 2 events
# CRL_TREATED_SAMEMKT_DIFFTECH has 46 events
# CRL_TREATED_DIFFMKT_SAMETECH has 3 events
# CSII_TREATING_SAMEMKT_SAMETECH has no events
# CSII_TREATING_SAMEMKT_DIFFTECH has no events
# CSII_TREATING_DIFFMKT_SAMETECH has no events
# CSII_TREATED_SAMEMKT_SAMETECH has no events
# CSII_TREATED_SAMEMKT_DIFFTECH has 3 events
# CSII_TREATED_DIFFMKT_SAMETECH has no events
# CSL_TREATING_SAMEMKT_SAMETECH has no events
# CSL_TREATING_SAMEMKT_DIFFTECH has 108 events
# CSL_TREATING_DIFFMKT_SAMETECH has 10 events
# CSL_TREATED_SAMEMKT_SAMETECH has no events
# CSL_TREATED_SAMEMKT_DIFFTECH has 70 events
# CSL_TREATED_DIFFMKT_SAMETECH has 4 events
# CTIC_TREATING_SAMEMKT_SAMETECH has no events
# CTIC_TREATING_SAMEMKT_DIFFTECH has 89 events
# CTIC_TREATING_DIFFMKT_SAMETECH has 2 events
# CTIC_TREATED_SAMEMKT_SAMETECH has 1 events
# CTIC_TREATED_SAMEMKT_DIFFTECH has 1150 events
# CTIC_TREATED_DIFFMKT_SAMETECH has 25 events
# CUR_TREATING_SAMEMKT_SAMETECH has no events
# CUR_TREATING_SAMEMKT_DIFFTECH has no events
# CUR_TREATING_DIFFMKT_SAMETECH has no events
# CUR_TREATED_SAMEMKT_SAMETECH has no events
# CUR_TREATED_SAMEMKT_DIFFTECH has no events
# CUR_TREATED_DIFFMKT_SAMETECH has no events
# CVM_TREATING_SAMEMKT_SAMETECH has no events
# CVM_TREATING_SAMEMKT_DIFFTECH has no events
# CVM_TREATING_DIFFMKT_SAMETECH has no events
# CVM_TREATED_SAMEMKT_SAMETECH has no events
# CVM_TREATED_SAMEMKT_DIFFTECH has 149 events
# CVM_TREATED_DIFFMKT_SAMETECH has 2 events
# CXR_TREATING_SAMEMKT_SAMETECH has no events
# CXR_TREATING_SAMEMKT_DIFFTECH has no events
# CXR_TREATING_DIFFMKT_SAMETECH has no events
# CXR_TREATED_SAMEMKT_SAMETECH has no events
# CXR_TREATED_SAMEMKT_DIFFTECH has 140 events
# CXR_TREATED_DIFFMKT_SAMETECH has 2 events
# DNAI_TREATING_SAMEMKT_SAMETECH has no events
# DNAI_TREATING_SAMEMKT_DIFFTECH has no events
# DNAI_TREATING_DIFFMKT_SAMETECH has no events
# DNAI_TREATED_SAMEMKT_SAMETECH has no events
# DNAI_TREATED_SAMEMKT_DIFFTECH has 17 events
# DNAI_TREATED_DIFFMKT_SAMETECH has no events
# DVA_TREATING_SAMEMKT_SAMETECH has no events
# DVA_TREATING_SAMEMKT_DIFFTECH has no events
# DVA_TREATING_DIFFMKT_SAMETECH has no events
# DVA_TREATED_SAMEMKT_SAMETECH has no events
# DVA_TREATED_SAMEMKT_DIFFTECH has no events
# DVA_TREATED_DIFFMKT_SAMETECH has no events
# ENDP_TREATING_SAMEMKT_SAMETECH has 5 events
# ENDP_TREATING_SAMEMKT_DIFFTECH has 334 events
# ENDP_TREATING_DIFFMKT_SAMETECH has 39 events
# ENDP_TREATED_SAMEMKT_SAMETECH has no events
# ENDP_TREATED_SAMEMKT_DIFFTECH has 849 events
# ENDP_TREATED_DIFFMKT_SAMETECH has 75 events
# ENMD_TREATING_SAMEMKT_SAMETECH has no events
# ENMD_TREATING_SAMEMKT_DIFFTECH has no events
# ENMD_TREATING_DIFFMKT_SAMETECH has no events
# ENMD_TREATED_SAMEMKT_SAMETECH has no events
# ENMD_TREATED_SAMEMKT_DIFFTECH has no events
# ENMD_TREATED_DIFFMKT_SAMETECH has no events
# ERI_TREATING_SAMEMKT_SAMETECH has no events
# ERI_TREATING_SAMEMKT_DIFFTECH has no events
# ERI_TREATING_DIFFMKT_SAMETECH has no events
# ERI_TREATED_SAMEMKT_SAMETECH has no events
# ERI_TREATED_SAMEMKT_DIFFTECH has no events
# ERI_TREATED_DIFFMKT_SAMETECH has no events
# ETX_TREATING_SAMEMKT_SAMETECH has no events
# ETX_TREATING_SAMEMKT_DIFFTECH has no events
# ETX_TREATING_DIFFMKT_SAMETECH has no events
# ETX_TREATED_SAMEMKT_SAMETECH has no events
# ETX_TREATED_SAMEMKT_DIFFTECH has 23 events
# ETX_TREATED_DIFFMKT_SAMETECH has no events
# EVK_TREATING_SAMEMKT_SAMETECH has 6 events
# EVK_TREATING_SAMEMKT_DIFFTECH has 361 events
# EVK_TREATING_DIFFMKT_SAMETECH has 67 events
# EVK_TREATED_SAMEMKT_SAMETECH has 2 events
# EVK_TREATED_SAMEMKT_DIFFTECH has 52 events
# EVK_TREATED_DIFFMKT_SAMETECH has 26 events
# FATE_TREATING_SAMEMKT_SAMETECH has no events
# FATE_TREATING_SAMEMKT_DIFFTECH has no events
# FATE_TREATING_DIFFMKT_SAMETECH has no events
# FATE_TREATED_SAMEMKT_SAMETECH has no events
# FATE_TREATED_SAMEMKT_DIFFTECH has 2 events
# FATE_TREATED_DIFFMKT_SAMETECH has no events
# FO_TREATING_SAMEMKT_SAMETECH has no events
# FO_TREATING_SAMEMKT_DIFFTECH has no events
# FO_TREATING_DIFFMKT_SAMETECH has no events
# FO_TREATED_SAMEMKT_SAMETECH has no events
# FO_TREATED_SAMEMKT_DIFFTECH has no events
# FO_TREATED_DIFFMKT_SAMETECH has no events
# FOLD_TREATING_SAMEMKT_SAMETECH has no events
# FOLD_TREATING_SAMEMKT_DIFFTECH has 73 events
# FOLD_TREATING_DIFFMKT_SAMETECH has 2 events
# FOLD_TREATED_SAMEMKT_SAMETECH has no events
# FOLD_TREATED_SAMEMKT_DIFFTECH has 55 events
# FOLD_TREATED_DIFFMKT_SAMETECH has no events
# FRE_TREATING_SAMEMKT_SAMETECH has no events
# FRE_TREATING_SAMEMKT_DIFFTECH has no events
# FRE_TREATING_DIFFMKT_SAMETECH has no events
# FRE_TREATED_SAMEMKT_SAMETECH has no events
# FRE_TREATED_SAMEMKT_DIFFTECH has 64 events
# FRE_TREATED_DIFFMKT_SAMETECH has no events
# GALE_TREATING_SAMEMKT_SAMETECH has no events
# GALE_TREATING_SAMEMKT_DIFFTECH has no events
# GALE_TREATING_DIFFMKT_SAMETECH has no events
# GALE_TREATED_SAMEMKT_SAMETECH has no events
# GALE_TREATED_SAMEMKT_DIFFTECH has 41 events
# GALE_TREATED_DIFFMKT_SAMETECH has no events
# GEVA_TREATING_SAMEMKT_SAMETECH has no events
# GEVA_TREATING_SAMEMKT_DIFFTECH has no events
# GEVA_TREATING_DIFFMKT_SAMETECH has no events
# GEVA_TREATED_SAMEMKT_SAMETECH has no events
# GEVA_TREATED_SAMEMKT_DIFFTECH has 1 events
# GEVA_TREATED_DIFFMKT_SAMETECH has 1 events
# GLGC_TREATING_SAMEMKT_SAMETECH has no events
# GLGC_TREATING_SAMEMKT_DIFFTECH has no events
# GLGC_TREATING_DIFFMKT_SAMETECH has no events
# GLGC_TREATED_SAMEMKT_SAMETECH has no events
# GLGC_TREATED_SAMEMKT_DIFFTECH has no events
# GLGC_TREATED_DIFFMKT_SAMETECH has no events
# GTA_TREATING_SAMEMKT_SAMETECH has no events
# GTA_TREATING_SAMEMKT_DIFFTECH has no events
# GTA_TREATING_DIFFMKT_SAMETECH has no events
# GTA_TREATED_SAMEMKT_SAMETECH has no events
# GTA_TREATED_SAMEMKT_DIFFTECH has no events
# GTA_TREATED_DIFFMKT_SAMETECH has no events
# HNR_TREATING_SAMEMKT_SAMETECH has no events
# HNR_TREATING_SAMEMKT_DIFFTECH has no events
# HNR_TREATING_DIFFMKT_SAMETECH has no events
# HNR_TREATED_SAMEMKT_SAMETECH has no events
# HNR_TREATED_SAMEMKT_DIFFTECH has no events
# HNR_TREATED_DIFFMKT_SAMETECH has no events
# HRTX_TREATING_SAMEMKT_SAMETECH has no events
# HRTX_TREATING_SAMEMKT_DIFFTECH has no events
# HRTX_TREATING_DIFFMKT_SAMETECH has no events
# HRTX_TREATED_SAMEMKT_SAMETECH has no events
# HRTX_TREATED_SAMEMKT_DIFFTECH has no events
# HRTX_TREATED_DIFFMKT_SAMETECH has no events
# ICO_TREATING_SAMEMKT_SAMETECH has no events
# ICO_TREATING_SAMEMKT_DIFFTECH has no events
# ICO_TREATING_DIFFMKT_SAMETECH has no events
# ICO_TREATED_SAMEMKT_SAMETECH has no events
# ICO_TREATED_SAMEMKT_DIFFTECH has 27 events
# ICO_TREATED_DIFFMKT_SAMETECH has no events
# ICOC_TREATING_SAMEMKT_SAMETECH has no events
# ICOC_TREATING_SAMEMKT_DIFFTECH has no events
# ICOC_TREATING_DIFFMKT_SAMETECH has no events
# ICOC_TREATED_SAMEMKT_SAMETECH has no events
# ICOC_TREATED_SAMEMKT_DIFFTECH has no events
# ICOC_TREATED_DIFFMKT_SAMETECH has no events
# IGL_TREATING_SAMEMKT_SAMETECH has no events
# IGL_TREATING_SAMEMKT_DIFFTECH has no events
# IGL_TREATING_DIFFMKT_SAMETECH has no events
# IGL_TREATED_SAMEMKT_SAMETECH has no events
# IGL_TREATED_SAMEMKT_DIFFTECH has no events
# IGL_TREATED_DIFFMKT_SAMETECH has no events
# IMA_TREATING_SAMEMKT_SAMETECH has no events
# IMA_TREATING_SAMEMKT_DIFFTECH has no events
# IMA_TREATING_DIFFMKT_SAMETECH has no events
# IMA_TREATED_SAMEMKT_SAMETECH has no events
# IMA_TREATED_SAMEMKT_DIFFTECH has no events
# IMA_TREATED_DIFFMKT_SAMETECH has no events
# INHL_TREATING_SAMEMKT_SAMETECH has no events
# INHL_TREATING_SAMEMKT_DIFFTECH has no events
# INHL_TREATING_DIFFMKT_SAMETECH has no events
# INHL_TREATED_SAMEMKT_SAMETECH has no events
# INHL_TREATED_SAMEMKT_DIFFTECH has no events
# INHL_TREATED_DIFFMKT_SAMETECH has no events
# INSY_TREATING_SAMEMKT_SAMETECH has no events
# INSY_TREATING_SAMEMKT_DIFFTECH has 10 events
# INSY_TREATING_DIFFMKT_SAMETECH has 68 events
# INSY_TREATED_SAMEMKT_SAMETECH has no events
# INSY_TREATED_SAMEMKT_DIFFTECH has 445 events
# INSY_TREATED_DIFFMKT_SAMETECH has 51 events
# IPCI_TREATING_SAMEMKT_SAMETECH has no events
# IPCI_TREATING_SAMEMKT_DIFFTECH has no events
# IPCI_TREATING_DIFFMKT_SAMETECH has no events
# IPCI_TREATED_SAMEMKT_SAMETECH has no events
# IPCI_TREATED_SAMEMKT_DIFFTECH has 89 events
# IPCI_TREATED_DIFFMKT_SAMETECH has no events
# JAZZ_TREATING_SAMEMKT_SAMETECH has no events
# JAZZ_TREATING_SAMEMKT_DIFFTECH has 43 events
# JAZZ_TREATING_DIFFMKT_SAMETECH has 12 events
# JAZZ_TREATED_SAMEMKT_SAMETECH has 3 events
# JAZZ_TREATED_SAMEMKT_DIFFTECH has 197 events
# JAZZ_TREATED_DIFFMKT_SAMETECH has 37 events
# JCS_TREATING_SAMEMKT_SAMETECH has no events
# JCS_TREATING_SAMEMKT_DIFFTECH has no events
# JCS_TREATING_DIFFMKT_SAMETECH has no events
# JCS_TREATED_SAMEMKT_SAMETECH has no events
# JCS_TREATED_SAMEMKT_DIFFTECH has no events
# JCS_TREATED_DIFFMKT_SAMETECH has no events
# JNJ_TREATING_SAMEMKT_SAMETECH has 14 events
# JNJ_TREATING_SAMEMKT_DIFFTECH has 1845 events
# JNJ_TREATING_DIFFMKT_SAMETECH has 185 events
# JNJ_TREATED_SAMEMKT_SAMETECH has 52 events
# JNJ_TREATED_SAMEMKT_DIFFTECH has 3659 events
# JNJ_TREATED_DIFFMKT_SAMETECH has 371 events
# JNP_TREATING_SAMEMKT_SAMETECH has no events
# JNP_TREATING_SAMEMKT_DIFFTECH has no events
# JNP_TREATING_DIFFMKT_SAMETECH has no events
# JNP_TREATED_SAMEMKT_SAMETECH has no events
# JNP_TREATED_SAMEMKT_DIFFTECH has 13 events
# JNP_TREATED_DIFFMKT_SAMETECH has 13 events
# KBIO_TREATING_SAMEMKT_SAMETECH has no events
# KBIO_TREATING_SAMEMKT_DIFFTECH has 480 events
# KBIO_TREATING_DIFFMKT_SAMETECH has 3 events
# KBIO_TREATED_SAMEMKT_SAMETECH has no events
# KBIO_TREATED_SAMEMKT_DIFFTECH has 181 events
# KBIO_TREATED_DIFFMKT_SAMETECH has 2 events
# KERX_TREATING_SAMEMKT_SAMETECH has 7 events
# KERX_TREATING_SAMEMKT_DIFFTECH has 1451 events
# KERX_TREATING_DIFFMKT_SAMETECH has 313 events
# KERX_TREATED_SAMEMKT_SAMETECH has 2 events
# KERX_TREATED_SAMEMKT_DIFFTECH has 1092 events
# KERX_TREATED_DIFFMKT_SAMETECH has 78 events
# KG_TREATING_SAMEMKT_SAMETECH has no events
# KG_TREATING_SAMEMKT_DIFFTECH has no events
# KG_TREATING_DIFFMKT_SAMETECH has no events
# KG_TREATED_SAMEMKT_SAMETECH has no events
# KG_TREATED_SAMEMKT_DIFFTECH has no events
# KG_TREATED_DIFFMKT_SAMETECH has no events
# KING_TREATING_SAMEMKT_SAMETECH has no events
# KING_TREATING_SAMEMKT_DIFFTECH has no events
# KING_TREATING_DIFFMKT_SAMETECH has no events
# KING_TREATED_SAMEMKT_SAMETECH has no events
# KING_TREATED_SAMEMKT_DIFFTECH has no events
# KING_TREATED_DIFFMKT_SAMETECH has no events
# KITE_TREATING_SAMEMKT_SAMETECH has no events
# KITE_TREATING_SAMEMKT_DIFFTECH has no events
# KITE_TREATING_DIFFMKT_SAMETECH has no events
# KITE_TREATED_SAMEMKT_SAMETECH has no events
# KITE_TREATED_SAMEMKT_DIFFTECH has 2 events
# KITE_TREATED_DIFFMKT_SAMETECH has no events
# KMDA_TREATING_SAMEMKT_SAMETECH has no events
# KMDA_TREATING_SAMEMKT_DIFFTECH has no events
# KMDA_TREATING_DIFFMKT_SAMETECH has no events
# KMDA_TREATED_SAMEMKT_SAMETECH has no events
# KMDA_TREATED_SAMEMKT_DIFFTECH has 56 events
# KMDA_TREATED_DIFFMKT_SAMETECH has no events
# KOSN_TREATING_SAMEMKT_SAMETECH has no events
# KOSN_TREATING_SAMEMKT_DIFFTECH has no events
# KOSN_TREATING_DIFFMKT_SAMETECH has no events
# KOSN_TREATED_SAMEMKT_SAMETECH has no events
# KOSN_TREATED_SAMEMKT_DIFFTECH has no events
# KOSN_TREATED_DIFFMKT_SAMETECH has no events
# KOSP_TREATING_SAMEMKT_SAMETECH has no events
# KOSP_TREATING_SAMEMKT_DIFFTECH has no events
# KOSP_TREATING_DIFFMKT_SAMETECH has no events
# KOSP_TREATED_SAMEMKT_SAMETECH has no events
# KOSP_TREATED_SAMEMKT_DIFFTECH has no events
# KOSP_TREATED_DIFFMKT_SAMETECH has no events
# KPTI_TREATING_SAMEMKT_SAMETECH has no events
# KPTI_TREATING_SAMEMKT_DIFFTECH has no events
# KPTI_TREATING_DIFFMKT_SAMETECH has no events
# KPTI_TREATED_SAMEMKT_SAMETECH has no events
# KPTI_TREATED_SAMEMKT_DIFFTECH has 8 events
# KPTI_TREATED_DIFFMKT_SAMETECH has no events
# KYTH_TREATING_SAMEMKT_SAMETECH has no events
# KYTH_TREATING_SAMEMKT_DIFFTECH has no events
# KYTH_TREATING_DIFFMKT_SAMETECH has no events
# KYTH_TREATED_SAMEMKT_SAMETECH has no events
# KYTH_TREATED_SAMEMKT_DIFFTECH has 4 events
# KYTH_TREATED_DIFFMKT_SAMETECH has no events
# LBIO_TREATING_SAMEMKT_SAMETECH has no events
# LBIO_TREATING_SAMEMKT_DIFFTECH has no events
# LBIO_TREATING_DIFFMKT_SAMETECH has no events
# LBIO_TREATED_SAMEMKT_SAMETECH has no events
# LBIO_TREATED_SAMEMKT_DIFFTECH has no events
# LBIO_TREATED_DIFFMKT_SAMETECH has no events
# LEXG_TREATING_SAMEMKT_SAMETECH has no events
# LEXG_TREATING_SAMEMKT_DIFFTECH has no events
# LEXG_TREATING_DIFFMKT_SAMETECH has no events
# LEXG_TREATED_SAMEMKT_SAMETECH has no events
# LEXG_TREATED_SAMEMKT_DIFFTECH has no events
# LEXG_TREATED_DIFFMKT_SAMETECH has no events
# LGND_TREATING_SAMEMKT_SAMETECH has 8 events
# LGND_TREATING_SAMEMKT_DIFFTECH has 1675 events
# LGND_TREATING_DIFFMKT_SAMETECH has 99 events
# LGND_TREATED_SAMEMKT_SAMETECH has 6 events
# LGND_TREATED_SAMEMKT_DIFFTECH has 1090 events
# LGND_TREATED_DIFFMKT_SAMETECH has 98 events
# LGNDA_TREATING_SAMEMKT_SAMETECH has no events
# LGNDA_TREATING_SAMEMKT_DIFFTECH has no events
# LGNDA_TREATING_DIFFMKT_SAMETECH has no events
# LGNDA_TREATED_SAMEMKT_SAMETECH has no events
# LGNDA_TREATED_SAMEMKT_DIFFTECH has no events
# LGNDA_TREATED_DIFFMKT_SAMETECH has no events
# LIFC_TREATING_SAMEMKT_SAMETECH has no events
# LIFC_TREATING_SAMEMKT_DIFFTECH has no events
# LIFC_TREATING_DIFFMKT_SAMETECH has no events
# LIFC_TREATED_SAMEMKT_SAMETECH has no events
# LIFC_TREATED_SAMEMKT_DIFFTECH has no events
# LIFC_TREATED_DIFFMKT_SAMETECH has no events
# ...
# STD_TREATED_SAMEMKT_DIFFTECH has no events
# STD_TREATED_DIFFMKT_SAMETECH has no events
# STEM_TREATING_SAMEMKT_SAMETECH has no events
# STEM_TREATING_SAMEMKT_DIFFTECH has 17 events
# STEM_TREATING_DIFFMKT_SAMETECH has no events
# STEM_TREATED_SAMEMKT_SAMETECH has no events
# STEM_TREATED_SAMEMKT_DIFFTECH has 5 events
# STEM_TREATED_DIFFMKT_SAMETECH has no events
# STML_TREATING_SAMEMKT_SAMETECH has no events
# STML_TREATING_SAMEMKT_DIFFTECH has no events
# STML_TREATING_DIFFMKT_SAMETECH has no events
# STML_TREATED_SAMEMKT_SAMETECH has no events
# STML_TREATED_SAMEMKT_DIFFTECH has 120 events
# STML_TREATED_DIFFMKT_SAMETECH has no events
# SUPN_TREATING_SAMEMKT_SAMETECH has no events
# SUPN_TREATING_SAMEMKT_DIFFTECH has no events
# SUPN_TREATING_DIFFMKT_SAMETECH has no events
# SUPN_TREATED_SAMEMKT_SAMETECH has no events
# SUPN_TREATED_SAMEMKT_DIFFTECH has 15 events
# SUPN_TREATED_DIFFMKT_SAMETECH has 4 events
# SVA_TREATING_SAMEMKT_SAMETECH has no events
# SVA_TREATING_SAMEMKT_DIFFTECH has no events
# SVA_TREATING_DIFFMKT_SAMETECH has no events
# SVA_TREATED_SAMEMKT_SAMETECH has no events
# SVA_TREATED_SAMEMKT_DIFFTECH has 7 events
# SVA_TREATED_DIFFMKT_SAMETECH has no events
# SVBL_TREATING_SAMEMKT_SAMETECH has no events
# SVBL_TREATING_SAMEMKT_DIFFTECH has no events
# SVBL_TREATING_DIFFMKT_SAMETECH has no events
# SVBL_TREATED_SAMEMKT_SAMETECH has no events
# SVBL_TREATED_SAMEMKT_DIFFTECH has no events
# SVBL_TREATED_DIFFMKT_SAMETECH has no events
# SYI_TREATING_SAMEMKT_SAMETECH has no events
# SYI_TREATING_SAMEMKT_DIFFTECH has no events
# SYI_TREATING_DIFFMKT_SAMETECH has no events
# SYI_TREATED_SAMEMKT_SAMETECH has no events
# SYI_TREATED_SAMEMKT_DIFFTECH has no events
# SYI_TREATED_DIFFMKT_SAMETECH has no events
# SYN_TREATING_SAMEMKT_SAMETECH has no events
# SYN_TREATING_SAMEMKT_DIFFTECH has 26 events
# SYN_TREATING_DIFFMKT_SAMETECH has 7 events
# SYN_TREATED_SAMEMKT_SAMETECH has no events
# SYN_TREATED_SAMEMKT_DIFFTECH has 104 events
# SYN_TREATED_DIFFMKT_SAMETECH has 32 events
# TARO_TREATING_SAMEMKT_SAMETECH has no events
# TARO_TREATING_SAMEMKT_DIFFTECH has no events
# TARO_TREATING_DIFFMKT_SAMETECH has no events
# TARO_TREATED_SAMEMKT_SAMETECH has no events
# TARO_TREATED_SAMEMKT_DIFFTECH has 20 events
# TARO_TREATED_DIFFMKT_SAMETECH has no events
# TBRA_TREATING_SAMEMKT_SAMETECH has no events
# TBRA_TREATING_SAMEMKT_DIFFTECH has no events
# TBRA_TREATING_DIFFMKT_SAMETECH has no events
# TBRA_TREATED_SAMEMKT_SAMETECH has no events
# TBRA_TREATED_SAMEMKT_DIFFTECH has no events
# TBRA_TREATED_DIFFMKT_SAMETECH has 8 events
# TCON_TREATING_SAMEMKT_SAMETECH has no events
# TCON_TREATING_SAMEMKT_DIFFTECH has no events
# TCON_TREATING_DIFFMKT_SAMETECH has no events
# TCON_TREATED_SAMEMKT_SAMETECH has no events
# TCON_TREATED_SAMEMKT_DIFFTECH has 133 events
# TCON_TREATED_DIFFMKT_SAMETECH has no events
# TEVA_TREATING_SAMEMKT_SAMETECH has 16 events
# TEVA_TREATING_SAMEMKT_DIFFTECH has 2422 events
# TEVA_TREATING_DIFFMKT_SAMETECH has 324 events
# TEVA_TREATED_SAMEMKT_SAMETECH has 11 events
# TEVA_TREATED_SAMEMKT_DIFFTECH has 3154 events
# TEVA_TREATED_DIFFMKT_SAMETECH has 324 events
# TGEN_TREATING_SAMEMKT_SAMETECH has no events
# TGEN_TREATING_SAMEMKT_DIFFTECH has no events
# TGEN_TREATING_DIFFMKT_SAMETECH has no events
# TGEN_TREATED_SAMEMKT_SAMETECH has no events
# TGEN_TREATED_SAMEMKT_DIFFTECH has no events
# TGEN_TREATED_DIFFMKT_SAMETECH has no events
# TGTX_TREATING_SAMEMKT_SAMETECH has 2 events
# TGTX_TREATING_SAMEMKT_DIFFTECH has 161 events
# TGTX_TREATING_DIFFMKT_SAMETECH has 12 events
# TGTX_TREATED_SAMEMKT_SAMETECH has no events
# TGTX_TREATED_SAMEMKT_DIFFTECH has 133 events
# TGTX_TREATED_DIFFMKT_SAMETECH has 3 events
# TGX_TREATING_SAMEMKT_SAMETECH has no events
# TGX_TREATING_SAMEMKT_DIFFTECH has no events
# TGX_TREATING_DIFFMKT_SAMETECH has no events
# TGX_TREATED_SAMEMKT_SAMETECH has no events
# TGX_TREATED_SAMEMKT_DIFFTECH has no events
# TGX_TREATED_DIFFMKT_SAMETECH has no events
# THLD_TREATING_SAMEMKT_SAMETECH has no events
# THLD_TREATING_SAMEMKT_DIFFTECH has 61 events
# THLD_TREATING_DIFFMKT_SAMETECH has no events
# THLD_TREATED_SAMEMKT_SAMETECH has no events
# THLD_TREATED_SAMEMKT_DIFFTECH has 126 events
# THLD_TREATED_DIFFMKT_SAMETECH has no events
# THRX_TREATING_SAMEMKT_SAMETECH has no events
# THRX_TREATING_SAMEMKT_DIFFTECH has no events
# THRX_TREATING_DIFFMKT_SAMETECH has no events
# THRX_TREATED_SAMEMKT_SAMETECH has 1 events
# THRX_TREATED_SAMEMKT_DIFFTECH has 216 events
# THRX_TREATED_DIFFMKT_SAMETECH has 5 events
# TKMR_TREATING_SAMEMKT_SAMETECH has no events
# TKMR_TREATING_SAMEMKT_DIFFTECH has no events
# TKMR_TREATING_DIFFMKT_SAMETECH has no events
# TKMR_TREATED_SAMEMKT_SAMETECH has no events
# TKMR_TREATED_SAMEMKT_DIFFTECH has no events
# TKMR_TREATED_DIFFMKT_SAMETECH has no events
# TLOG_TREATING_SAMEMKT_SAMETECH has no events
# TLOG_TREATING_SAMEMKT_DIFFTECH has no events
# TLOG_TREATING_DIFFMKT_SAMETECH has no events
# TLOG_TREATED_SAMEMKT_SAMETECH has no events
# TLOG_TREATED_SAMEMKT_DIFFTECH has 165 events
# TLOG_TREATED_DIFFMKT_SAMETECH has 2 events
# TMX_TREATING_SAMEMKT_SAMETECH has no events
# TMX_TREATING_SAMEMKT_DIFFTECH has 102 events
# TMX_TREATING_DIFFMKT_SAMETECH has 1 events
# TMX_TREATED_SAMEMKT_SAMETECH has no events
# TMX_TREATED_SAMEMKT_DIFFTECH has 47 events
# TMX_TREATED_DIFFMKT_SAMETECH has 3 events
# TNXP_TREATING_SAMEMKT_SAMETECH has no events
# TNXP_TREATING_SAMEMKT_DIFFTECH has no events
# TNXP_TREATING_DIFFMKT_SAMETECH has no events
# TNXP_TREATED_SAMEMKT_SAMETECH has 1 events
# TNXP_TREATED_SAMEMKT_DIFFTECH has 11 events
# TNXP_TREATED_DIFFMKT_SAMETECH has 3 events
# TPTX_TREATING_SAMEMKT_SAMETECH has no events
# TPTX_TREATING_SAMEMKT_DIFFTECH has no events
# TPTX_TREATING_DIFFMKT_SAMETECH has no events
# TPTX_TREATED_SAMEMKT_SAMETECH has no events
# TPTX_TREATED_SAMEMKT_DIFFTECH has no events
# TPTX_TREATED_DIFFMKT_SAMETECH has no events
# TR_TREATING_SAMEMKT_SAMETECH has no events
# TR_TREATING_SAMEMKT_DIFFTECH has no events
# TR_TREATING_DIFFMKT_SAMETECH has no events
# TR_TREATED_SAMEMKT_SAMETECH has no events
# TR_TREATED_SAMEMKT_DIFFTECH has 23 events
# TR_TREATED_DIFFMKT_SAMETECH has 1 events
# TRGT_TREATING_SAMEMKT_SAMETECH has no events
# TRGT_TREATING_SAMEMKT_DIFFTECH has no events
# TRGT_TREATING_DIFFMKT_SAMETECH has no events
# TRGT_TREATED_SAMEMKT_SAMETECH has no events
# TRGT_TREATED_SAMEMKT_DIFFTECH has no events
# TRGT_TREATED_DIFFMKT_SAMETECH has no events
# TRMS_TREATING_SAMEMKT_SAMETECH has no events
# TRMS_TREATING_SAMEMKT_DIFFTECH has no events
# TRMS_TREATING_DIFFMKT_SAMETECH has no events
# TRMS_TREATED_SAMEMKT_SAMETECH has no events
# TRMS_TREATED_SAMEMKT_DIFFTECH has no events
# TRMS_TREATED_DIFFMKT_SAMETECH has no events
# TRVN_TREATING_SAMEMKT_SAMETECH has no events
# TRVN_TREATING_SAMEMKT_DIFFTECH has no events
# TRVN_TREATING_DIFFMKT_SAMETECH has no events
# TRVN_TREATED_SAMEMKT_SAMETECH has no events
# TRVN_TREATED_SAMEMKT_DIFFTECH has 4 events
# TRVN_TREATED_DIFFMKT_SAMETECH has no events
# TSPT_TREATING_SAMEMKT_SAMETECH has no events
# TSPT_TREATING_SAMEMKT_DIFFTECH has no events
# TSPT_TREATING_DIFFMKT_SAMETECH has no events
# TSPT_TREATED_SAMEMKT_SAMETECH has no events
# TSPT_TREATED_SAMEMKT_DIFFTECH has no events
# TSPT_TREATED_DIFFMKT_SAMETECH has no events
# TSRO_TREATING_SAMEMKT_SAMETECH has no events
# TSRO_TREATING_SAMEMKT_DIFFTECH has no events
# TSRO_TREATING_DIFFMKT_SAMETECH has no events
# TSRO_TREATED_SAMEMKT_SAMETECH has no events
# TSRO_TREATED_SAMEMKT_DIFFTECH has 37 events
# TSRO_TREATED_DIFFMKT_SAMETECH has 5 events
# TTH_TREATING_SAMEMKT_SAMETECH has no events
# TTH_TREATING_SAMEMKT_DIFFTECH has 48 events
# TTH_TREATING_DIFFMKT_SAMETECH has no events
# TTH_TREATED_SAMEMKT_SAMETECH has no events
# TTH_TREATED_SAMEMKT_DIFFTECH has 130 events
# TTH_TREATED_DIFFMKT_SAMETECH has no events
# TTNP_TREATING_SAMEMKT_SAMETECH has no events
# TTNP_TREATING_SAMEMKT_DIFFTECH has 105 events
# TTNP_TREATING_DIFFMKT_SAMETECH has 24 events
# TTNP_TREATED_SAMEMKT_SAMETECH has no events
# TTNP_TREATED_SAMEMKT_DIFFTECH has 410 events
# TTNP_TREATED_DIFFMKT_SAMETECH has 4 events
# TTP_TREATING_SAMEMKT_SAMETECH has no events
# TTP_TREATING_SAMEMKT_DIFFTECH has no events
# TTP_TREATING_DIFFMKT_SAMETECH has no events
# TTP_TREATED_SAMEMKT_SAMETECH has no events
# TTP_TREATED_SAMEMKT_DIFFTECH has no events
# TTP_TREATED_DIFFMKT_SAMETECH has no events
# TTPH_TREATING_SAMEMKT_SAMETECH has no events
# TTPH_TREATING_SAMEMKT_DIFFTECH has no events
# TTPH_TREATING_DIFFMKT_SAMETECH has no events
# TTPH_TREATED_SAMEMKT_SAMETECH has no events
# TTPH_TREATED_SAMEMKT_DIFFTECH has 2 events
# TTPH_TREATED_DIFFMKT_SAMETECH has no events
# TZYM_TREATING_SAMEMKT_SAMETECH has no events
# TZYM_TREATING_SAMEMKT_DIFFTECH has no events
# TZYM_TREATING_DIFFMKT_SAMETECH has no events
# TZYM_TREATED_SAMEMKT_SAMETECH has no events
# TZYM_TREATED_SAMEMKT_DIFFTECH has no events
# TZYM_TREATED_DIFFMKT_SAMETECH has no events
# UTHR_TREATING_SAMEMKT_SAMETECH has no events
# UTHR_TREATING_SAMEMKT_DIFFTECH has 11 events
# UTHR_TREATING_DIFFMKT_SAMETECH has 1 events
# UTHR_TREATED_SAMEMKT_SAMETECH has no events
# UTHR_TREATED_SAMEMKT_DIFFTECH has 95 events
# UTHR_TREATED_DIFFMKT_SAMETECH has no events
# VEC_TREATING_SAMEMKT_SAMETECH has no events
# VEC_TREATING_SAMEMKT_DIFFTECH has 320 events
# VEC_TREATING_DIFFMKT_SAMETECH has no events
# VEC_TREATED_SAMEMKT_SAMETECH has no events
# VEC_TREATED_SAMEMKT_DIFFTECH has 281 events
# VEC_TREATED_DIFFMKT_SAMETECH has 19 events
# VEGF_TREATING_SAMEMKT_SAMETECH has no events
# VEGF_TREATING_SAMEMKT_DIFFTECH has no events
# VEGF_TREATING_DIFFMKT_SAMETECH has no events
# VEGF_TREATED_SAMEMKT_SAMETECH has no events
# VEGF_TREATED_SAMEMKT_DIFFTECH has no events
# VEGF_TREATED_DIFFMKT_SAMETECH has no events
# VER_TREATING_SAMEMKT_SAMETECH has 7 events
# VER_TREATING_SAMEMKT_DIFFTECH has 411 events
# VER_TREATING_DIFFMKT_SAMETECH has 112 events
# VER_TREATED_SAMEMKT_SAMETECH has 3 events
# VER_TREATED_SAMEMKT_DIFFTECH has 360 events
# VER_TREATED_DIFFMKT_SAMETECH has 107 events
# VIAP_TREATING_SAMEMKT_SAMETECH has 1 events
# VIAP_TREATING_SAMEMKT_DIFFTECH has 50 events
# VIAP_TREATING_DIFFMKT_SAMETECH has 21 events
# VIAP_TREATED_SAMEMKT_SAMETECH has no events
# VIAP_TREATED_SAMEMKT_DIFFTECH has 12 events
# VIAP_TREATED_DIFFMKT_SAMETECH has 12 events
# VICL_TREATING_SAMEMKT_SAMETECH has 1 events
# VICL_TREATING_SAMEMKT_DIFFTECH has 327 events
# VICL_TREATING_DIFFMKT_SAMETECH has 19 events
# VICL_TREATED_SAMEMKT_SAMETECH has 3 events
# VICL_TREATED_SAMEMKT_DIFFTECH has 82 events
# VICL_TREATED_DIFFMKT_SAMETECH has 11 events
# VION_TREATING_SAMEMKT_SAMETECH has no events
# VION_TREATING_SAMEMKT_DIFFTECH has no events
# VION_TREATING_DIFFMKT_SAMETECH has no events
# VION_TREATED_SAMEMKT_SAMETECH has no events
# VION_TREATED_SAMEMKT_DIFFTECH has no events
# VION_TREATED_DIFFMKT_SAMETECH has no events
# VMRX_TREATING_SAMEMKT_SAMETECH has no events
# VMRX_TREATING_SAMEMKT_DIFFTECH has no events
# VMRX_TREATING_DIFFMKT_SAMETECH has no events
# VMRX_TREATED_SAMEMKT_SAMETECH has no events
# VMRX_TREATED_SAMEMKT_DIFFTECH has no events
# VMRX_TREATED_DIFFMKT_SAMETECH has no events
# VNDA_TREATING_SAMEMKT_SAMETECH has no events
# VNDA_TREATING_SAMEMKT_DIFFTECH has 9 events
# VNDA_TREATING_DIFFMKT_SAMETECH has no events
# VNDA_TREATED_SAMEMKT_SAMETECH has 2 events
# VNDA_TREATED_SAMEMKT_DIFFTECH has 34 events
# VNDA_TREATED_DIFFMKT_SAMETECH has 4 events
# VRP_TREATING_SAMEMKT_SAMETECH has no events
# VRP_TREATING_SAMEMKT_DIFFTECH has no events
# VRP_TREATING_DIFFMKT_SAMETECH has no events
# VRP_TREATED_SAMEMKT_SAMETECH has no events
# VRP_TREATED_SAMEMKT_DIFFTECH has 49 events
# VRP_TREATED_DIFFMKT_SAMETECH has 13 events
# VRTX_TREATING_SAMEMKT_SAMETECH has 3 events
# VRTX_TREATING_SAMEMKT_DIFFTECH has 385 events
# VRTX_TREATING_DIFFMKT_SAMETECH has 20 events
# VRTX_TREATED_SAMEMKT_SAMETECH has 4 events
# VRTX_TREATED_SAMEMKT_DIFFTECH has 491 events
# VRTX_TREATED_DIFFMKT_SAMETECH has 32 events
# VRX_TREATING_SAMEMKT_SAMETECH has no events
# VRX_TREATING_SAMEMKT_DIFFTECH has 282 events
# VRX_TREATING_DIFFMKT_SAMETECH has 56 events
# VRX_TREATED_SAMEMKT_SAMETECH has no events
# VRX_TREATED_SAMEMKT_DIFFTECH has 449 events
# VRX_TREATED_DIFFMKT_SAMETECH has 53 events
# VSTM_TREATING_SAMEMKT_SAMETECH has no events
# VSTM_TREATING_SAMEMKT_DIFFTECH has no events
# VSTM_TREATING_DIFFMKT_SAMETECH has no events
# VSTM_TREATED_SAMEMKT_SAMETECH has no events
# VSTM_TREATED_SAMEMKT_DIFFTECH has 19 events
# VSTM_TREATED_DIFFMKT_SAMETECH has no events
# VTAE_TREATING_SAMEMKT_SAMETECH has no events
# VTAE_TREATING_SAMEMKT_DIFFTECH has no events
# VTAE_TREATING_DIFFMKT_SAMETECH has no events
# VTAE_TREATED_SAMEMKT_SAMETECH has no events
# VTAE_TREATED_SAMEMKT_DIFFTECH has 409 events
# VTAE_TREATED_DIFFMKT_SAMETECH has 11 events
# VVUS_TREATING_SAMEMKT_SAMETECH has no events
# VVUS_TREATING_SAMEMKT_DIFFTECH has no events
# VVUS_TREATING_DIFFMKT_SAMETECH has no events
# VVUS_TREATED_SAMEMKT_SAMETECH has no events
# VVUS_TREATED_SAMEMKT_DIFFTECH has 125 events
# VVUS_TREATED_DIFFMKT_SAMETECH has 5 events
# WPI_TREATING_SAMEMKT_SAMETECH has no events
# WPI_TREATING_SAMEMKT_DIFFTECH has no events
# WPI_TREATING_DIFFMKT_SAMETECH has no events
# WPI_TREATED_SAMEMKT_SAMETECH has no events
# WPI_TREATED_SAMEMKT_DIFFTECH has no events
# WPI_TREATED_DIFFMKT_SAMETECH has no events
# XENE_TREATING_SAMEMKT_SAMETECH has no events
# XENE_TREATING_SAMEMKT_DIFFTECH has no events
# XENE_TREATING_DIFFMKT_SAMETECH has no events
# XENE_TREATED_SAMEMKT_SAMETECH has 1 events
# XENE_TREATED_SAMEMKT_DIFFTECH has 59 events
# XENE_TREATED_DIFFMKT_SAMETECH has 2 events
# XLRN_TREATING_SAMEMKT_SAMETECH has 2 events
# XLRN_TREATING_SAMEMKT_DIFFTECH has 42 events
# XLRN_TREATING_DIFFMKT_SAMETECH has 6 events
# XLRN_TREATED_SAMEMKT_SAMETECH has 1 events
# XLRN_TREATED_SAMEMKT_DIFFTECH has 195 events
# XLRN_TREATED_DIFFMKT_SAMETECH has 16 events
# XNCR_TREATING_SAMEMKT_SAMETECH has no events
# XNCR_TREATING_SAMEMKT_DIFFTECH has no events
# XNCR_TREATING_DIFFMKT_SAMETECH has no events
# XNCR_TREATED_SAMEMKT_SAMETECH has no events
# XNCR_TREATED_SAMEMKT_DIFFTECH has 8 events
# XNCR_TREATED_DIFFMKT_SAMETECH has no events
# XNPT_TREATING_SAMEMKT_SAMETECH has no events
# XNPT_TREATING_SAMEMKT_DIFFTECH has no events
# XNPT_TREATING_DIFFMKT_SAMETECH has no events
# XNPT_TREATED_SAMEMKT_SAMETECH has 1 events
# XNPT_TREATED_SAMEMKT_DIFFTECH has 46 events
# XNPT_TREATED_DIFFMKT_SAMETECH has 3 events
# XOM_TREATING_SAMEMKT_SAMETECH has no events
# XOM_TREATING_SAMEMKT_DIFFTECH has no events
# XOM_TREATING_DIFFMKT_SAMETECH has no events
# XOM_TREATED_SAMEMKT_SAMETECH has no events
# XOM_TREATED_SAMEMKT_DIFFTECH has no events
# XOM_TREATED_DIFFMKT_SAMETECH has no events
# XOMA_TREATING_SAMEMKT_SAMETECH has 3 events
# XOMA_TREATING_SAMEMKT_DIFFTECH has 223 events
# XOMA_TREATING_DIFFMKT_SAMETECH has 18 events
# XOMA_TREATED_SAMEMKT_SAMETECH has 4 events
# XOMA_TREATED_SAMEMKT_DIFFTECH has 228 events
# XOMA_TREATED_DIFFMKT_SAMETECH has 19 events
# XON_TREATING_SAMEMKT_SAMETECH has no events
# XON_TREATING_SAMEMKT_DIFFTECH has no events
# XON_TREATING_DIFFMKT_SAMETECH has no events
# XON_TREATED_SAMEMKT_SAMETECH has no events
# XON_TREATED_SAMEMKT_DIFFTECH has 29 events
# XON_TREATED_DIFFMKT_SAMETECH has no events
# XTLB_TREATING_SAMEMKT_SAMETECH has no events
# XTLB_TREATING_SAMEMKT_DIFFTECH has no events
# XTLB_TREATING_DIFFMKT_SAMETECH has no events
# XTLB_TREATED_SAMEMKT_SAMETECH has no events
# XTLB_TREATED_SAMEMKT_DIFFTECH has 49 events
# XTLB_TREATED_DIFFMKT_SAMETECH has no events
# ZFGN_TREATING_SAMEMKT_SAMETECH has no events
# ZFGN_TREATING_SAMEMKT_DIFFTECH has no events
# ZFGN_TREATING_DIFFMKT_SAMETECH has no events
# ZFGN_TREATED_SAMEMKT_SAMETECH has no events
# ZFGN_TREATED_SAMEMKT_DIFFTECH has 8 events
# ZFGN_TREATED_DIFFMKT_SAMETECH has no events
# ZGNX_TREATING_SAMEMKT_SAMETECH has no events
# ZGNX_TREATING_SAMEMKT_DIFFTECH has no events
# ZGNX_TREATING_DIFFMKT_SAMETECH has no events
# ZGNX_TREATED_SAMEMKT_SAMETECH has no events
# ZGNX_TREATED_SAMEMKT_DIFFTECH has 16 events
# ZGNX_TREATED_DIFFMKT_SAMETECH has 1 events
# ZIOP_TREATING_SAMEMKT_SAMETECH has 1 events
# ZIOP_TREATING_SAMEMKT_DIFFTECH has 385 events
# ZIOP_TREATING_DIFFMKT_SAMETECH has 5 events
# ZIOP_TREATED_SAMEMKT_SAMETECH has no events
# ZIOP_TREATED_SAMEMKT_DIFFTECH has 64 events
# ZIOP_TREATED_DIFFMKT_SAMETECH has no events
# ZSAN_TREATING_SAMEMKT_SAMETECH has no events
# ZSAN_TREATING_SAMEMKT_DIFFTECH has no events
# ZSAN_TREATING_DIFFMKT_SAMETECH has no events
# ZSAN_TREATED_SAMEMKT_SAMETECH has no events
# ZSAN_TREATED_SAMEMKT_DIFFTECH has 4 events
# ZSAN_TREATED_DIFFMKT_SAMETECH has 2 events

# %%
fail_series = [
    create_own_drug_disc_dates(ticker, tt_ds) for ticker in UNIQUE_TICKERS]

# %%
flag_df = pd.concat(flag_series, axis=1).sort_index()
# Out:
# /Users/lrraymond13/.virtualenvs/ds3/lib/python2.7/site-packages/pandas/indexes/base.py:1746: FutureWarning:
#
# In the future, 'NAT < x' and 'x < NAT' will always be False.

# %%
fail_df = pd.concat(fail_series, axis=1).sort_index()

# %%
flag_df2 = pd.concat([flag_df, fail_df], axis=1).sort_index()

# %%
# clear memory
del flag_df, fail_df

# %%
# check if there are any CRSP tickers with no events and remove them
flag_tickers = set(map(lambda x: x.split('_')[0], flag_df2.columns))
extra_tickers = [x for x in UNIQUE_TICKERS if x not in flag_tickers]
print extra_tickers
# Out:
# []

# %%
cols_to_drop = ['{0}_{1}'.format(t, p) for t in extra_tickers for p in PIVOTS]
# print cols_to_drop
m3 = m2.drop(labels=cols_to_drop, axis=1)

# %%
del flag_series, m2

# %%
TREATING_DT in m3.columns
# Out:
# False

# %%
# now, merge the flag data set with the CRSP dataset
crsp_flag_dataset = pd.concat([flag_df2, m3], axis=1).sort_index()

# %%
# sort columns
crsp_flag_dataset = crsp_flag_dataset[sorted(crsp_flag_dataset.columns)]

# %%
d.pickle_upload_dataset(crsp_flag_dataset, '{}.p'.format(CRSP_FLAG_FNAME), DATA, DROPBOX_ANALYSIS_DATA)
# Out:
# Serializing to local path /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/crsp_event_flags.p
# Uploading /Users/lrraymond13/MIT/Kreiger_RA_2016/mkt_reaction_drug_failure/analysis/Data/crsp_event_flags.p to Dropbox as /data/intermediate/crsp_event_flags.p

# %%
crsp_flag_dataset.to_csv(os.path.join(DATA,'{}.csv'.format(CRSP_FLAG_FNAME)))

# %%
crsp_flag_dataset.head()
